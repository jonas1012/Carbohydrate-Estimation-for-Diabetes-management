# %% [markdown]
# In this script another larger ViT will be used as the backbone, since transformers has proven to have quite good performance. However the A100 hasnt been maxed out yet so let us see if that possibly can be done. Additionally will we also make use of the DINO model which should have enhanced spatial features, making it well suited for carbohydrate estimation.
#
# Furthermore was it also the model they used with RDINet (https://www.mdpi.com/2076-3417/16/1/454) with good results (but that was probably more down to the model getting information about the ingredients in a dish)

# %% [markdown]
# The first part of the code should be run on the CPU (dataset loading) before switching to the A100 for model training

# %% [markdown]
# Prerequisits

# %%
# !pip install -q pandas numpy

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Libraries

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %% [markdown]
# Configuration

# %%
DATASET_DIR = Path("/content/drive/MyDrive/Speciale/dataset/nutrition5k_compactV3")
METADATA_CSV = Path("/content/drive/MyDrive/Speciale/dataset/prepared_overhead_rgb_dataset/dish_carb_split_metadata.csv")

OUTPUT_DIR = Path("/content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PREP_DIR = OUTPUT_DIR / "prep_files"
PREP_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Dataset loading and splitting

# %%
df = pd.read_csv(METADATA_CSV)

print(df.head())
print(df["split"].value_counts())
print("Total rows:", len(df))
# Out:
#            dish_id  total_carb split source_cafe
# 0  dish_1556575327      10.618  test       cafe1
# 1  dish_1557861216       0.000  test       cafe1
# 2  dish_1557862345       0.000  test       cafe1
# 3  dish_1557862696       3.850  test       cafe1
# 4  dish_1557862738       0.000  test       cafe1
# split
# train    2421
# test      507
# val       334
# Name: count, dtype: int64
# Total rows: 3262

# %%
df["rgb_path"] = df["dish_id"].apply(
    lambda d: str(DATASET_DIR / str(d) / "overhead" / "rgb.png")
)

df["rgb_exists"] = df["rgb_path"].apply(lambda p: Path(p).exists())

print("Missing RGB images:", (~df["rgb_exists"]).sum())
# Out:
# Missing RGB images: 0

# %%
def file_size_or_minus1(path_str):
    p = Path(path_str)
    try:
        return p.stat().st_size
    except:
        return -1

df["rgb_size"] = df["rgb_path"].apply(file_size_or_minus1)

print("Empty RGB files:", (df["rgb_size"] <= 0).sum())

df = df[
    (df["rgb_exists"]) &
    (df["rgb_size"] > 0)
].copy()

print("\nRemaining samples after filtering:")
print(df["split"].value_counts())
print("Total remaining:", len(df))
# Out:
# Empty RGB files: 0
#
# Remaining samples after filtering:
# split
# train    2421
# test      507
# val       334
# Name: count, dtype: int64
# Total remaining: 3262

# %%
train_df = df[df["split"] == "train"].copy().reset_index(drop=True)
val_df   = df[df["split"] == "val"].copy().reset_index(drop=True)
test_df  = df[df["split"] == "test"].copy().reset_index(drop=True)

print("Train:", len(train_df))
print("Val:  ", len(val_df))
print("Test: ", len(test_df))
# Out:
# Train: 2421
# Val:   334
# Test:  507

# %%
train_csv = PREP_DIR / "train_rgb_only.csv"
val_csv   = PREP_DIR / "val_rgb_only.csv"
test_csv  = PREP_DIR / "test_rgb_only.csv"
full_csv  = PREP_DIR / "full_filtered_rgb_only.csv"

train_df.to_csv(train_csv, index=False)
val_df.to_csv(val_csv, index=False)
test_df.to_csv(test_csv, index=False)
df.to_csv(full_csv, index=False)

print("Saved:")
print(train_csv)
print(val_csv)
print(test_csv)
print(full_csv)
# Out:
# Saved:
# /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/prep_files/train_rgb_only.csv
# /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/prep_files/val_rgb_only.csv
# /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/prep_files/test_rgb_only.csv
# /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/prep_files/full_filtered_rgb_only.csv

# %% [markdown]
# Switch to GPU

# %% [markdown]
# Prerequisits

# %%
# !pip install -q keras-hub huggingface_hub

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import keras_hub

from huggingface_hub import notebook_login, HfApi

# %%
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Configuration

# %%
IMG_HEIGHT = 224
IMG_WIDTH  = 224
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE

STAGE1_EPOCHS = 100
STAGE2_EPOCHS = 200

STAGE1_LR = 2e-4
STAGE2_LR = 5e-6

# ---------------------------------------------------------
# Possible DINO options starting with dinov2_large
# DINOv2:
#   "dinov2_small"
#   "dinov2_base"
#   "dinov2_large"
#
# DINOv3:
#   "dinov3_vit_small_lvd1689m"
#   "dinov3_vit_small_plus_lvd1689m"
#   "dinov3_vit_base_lvd1689m"
#   "dinov3_vit_large_lvd1689m"
# ---------------------------------------------------------
BACKBONE_PRESET = "dinov2_large"

OUTPUT_DIR = Path("/content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PREP_DIR = OUTPUT_DIR / "prep_files"

train_csv = PREP_DIR / "train_rgb_only.csv"
val_csv   = PREP_DIR / "val_rgb_only.csv"
test_csv  = PREP_DIR / "test_rgb_only.csv"

# %% [markdown]
# Loading dataset paths and then later the images

# %%
train_df = pd.read_csv(train_csv)
val_df   = pd.read_csv(val_csv)
test_df  = pd.read_csv(test_csv)

print("Train:", len(train_df))
print("Val:  ", len(val_df))
print("Test: ", len(test_df))

display(train_df.head())
# Out:
# Train: 2421
# Val:   334
# Test:  507
#            dish_id  total_carb  split source_cafe  \
# 0  dish_1556572657       2.268  train       cafe1
# 1  dish_1556573514       1.219  train       cafe1
# 2  dish_1556575014       3.906  train       cafe1
# 3  dish_1556575083       5.760  train       cafe1
# 4  dish_1556575124       0.952  train       cafe1
#
#                                             rgb_path  rgb_exists  rgb_size
# 0  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    412129
# 1  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    432908
# 2  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    409854
# 3  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    396942
# 4  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    404314

# %%
def load_rgb_image(rgb_path):
    image = tf.io.read_file(rgb_path)
    image = tf.image.decode_png(image, channels=3)

    image = tf.image.resize_with_pad(
        image,
        target_height=IMG_HEIGHT,
        target_width=IMG_WIDTH,
        method=tf.image.ResizeMethod.BILINEAR,
        antialias=True
    )

    image = tf.cast(image, tf.float32)
    return image


def load_rgb_and_label(rgb_path, label):
    rgb = load_rgb_image(rgb_path)
    label = tf.cast(label, tf.float32)
    return {"rgb_input": rgb}, label


def make_dataset(dataframe, batch_size=16, shuffle=False):
    rgb_paths = dataframe["rgb_path"].values
    labels = dataframe["total_carb"].values.astype("float32")

    ds = tf.data.Dataset.from_tensor_slices((rgb_paths, labels))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=42)

    ds = ds.map(load_rgb_and_label, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(AUTOTUNE)

    return ds

# %%
train_dataset = make_dataset(train_df, batch_size=BATCH_SIZE, shuffle=True)
validation_dataset = make_dataset(val_df, batch_size=BATCH_SIZE, shuffle=False)
test_dataset = make_dataset(test_df, batch_size=BATCH_SIZE, shuffle=False)

for batch_inputs, batch_labels in train_dataset.take(1):
    print("RGB batch shape:", batch_inputs["rgb_input"].shape)
    print("Labels shape:   ", batch_labels.shape)
# Out:
# RGB batch shape: (16, 224, 224, 3)
# Labels shape:    (16,)

# %% [markdown]
# Showing an image in the dataset

# %%
for batch_inputs, batch_labels in train_dataset.take(1):
    sample_img = batch_inputs["rgb_input"][0].numpy().astype("uint8")
    sample_label = batch_labels[0].numpy()

    plt.figure(figsize=(5, 5))
    plt.imshow(sample_img)
    plt.title(f"Carbs = {sample_label:.2f}")
    plt.axis("off")
    plt.show()

# %% [markdown]
# Loading ViT backbone + image converter

# %%
image_converter = keras_hub.layers.ImageConverter.from_preset(
    BACKBONE_PRESET,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
)

backbone = keras_hub.models.Backbone.from_preset(
    BACKBONE_PRESET,
    image_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
)

backbone.trainable = False

print("Using preset:", BACKBONE_PRESET)
print("Image size:", (IMG_HEIGHT, IMG_WIDTH))
# Out:
# Using preset: dinov2_large
# Image size: (224, 224)

# %%
def extract_backbone_tensor(x):
    if isinstance(x, dict):
        preferred_keys = [
            "sequence_output",
            "pooled_output",
            "encoder_output",
            "token_embeddings",
            "hidden_states"
        ]
        for key in preferred_keys:
            if key in x:
                return x[key]
        return list(x.values())[0]
    return x

# %% [markdown]
# Model architecture

# %%
rgb_input = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3), name="rgb_input")

x = image_converter(rgb_input)
x = backbone(x)
x = extract_backbone_tensor(x)

if len(x.shape) == 3:
    x = layers.LayerNormalization()(x)
    x = layers.GlobalAveragePooling1D(name="token_pool")(x)
else:
    x = layers.LayerNormalization()(x)
    x = layers.Flatten()(x)

x = layers.Dropout(0.3)(x)
x = layers.Dense(256, activation="relu", name="dense_256")(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(64, activation="relu", name="dense_64")(x)
output = layers.Dense(1, activation="linear", name="carb_output")(x)

model = keras.Model(
    inputs={"rgb_input": rgb_input},
    outputs=output,
    name="rgb_only_dino_vit_regressor"
)

model.summary()
# Out:
# Model: "rgb_only_dino_vit_regressor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rgb_input (InputLayer)          │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dinov2_image_converter          │ (None, 224, 224, 3)    │             0 │
# │ (DINOV2ImageConverter)          │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dinov2_backbone                 │ (None, 257, 1024)      │   304,631,808 │
# │ (DINOV2Backbone)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_2           │ (None, 257, 1024)      │         2,048 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ token_pool                      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_64 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_256 (Dense)               │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_65 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ carb_output (Dense)             │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 304,912,769 (1.14 GB)
#  Trainable params: 280,961 (1.07 MB)
#  Non-trainable params: 304,631,808 (1.13 GB)

# %% [markdown]
# Stage 1 (here only a regression head will be trained)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=STAGE1_LR),
    loss="mse",
    metrics=[
        keras.metrics.MeanAbsoluteError(name="mae"),
        keras.metrics.MeanSquaredError(name="mse")
    ],
    jit_compile=False
)

# %%
stage1_best_path = OUTPUT_DIR / "best_model_stage1.weights.h5"

stage1_callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath=str(stage1_best_path),
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
        mode="min",
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=50,
        mode="min",
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=35,
        min_lr=1e-6,
        mode="min",
        verbose=1
    )
]

# %%
history_stage1 = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=STAGE1_EPOCHS,
    callbacks=stage1_callbacks
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 632.9226 - mae: 14.7691 - mse: 632.9226
# Epoch 1: val_loss improved from None to 160.70712, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 254ms/step - loss: 558.1503 - mae: 12.9204 - mse: 558.1503 - val_loss: 160.7071 - val_mae: 9.9264 - val_mse: 160.7071 - learning_rate: 2.0000e-04
# Epoch 2/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 186.1906 - mae: 9.9060 - mse: 186.1906
# Epoch 2: val_loss improved from 160.70712 to 108.01929, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 33s 219ms/step - loss: 447.8636 - mae: 10.1056 - mse: 447.8636 - val_loss: 108.0193 - val_mae: 8.1382 - val_mse: 108.0193 - learning_rate: 2.0000e-04
# Epoch 3/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 225.4351 - mae: 8.7203 - mse: 225.4351
# Epoch 3: val_loss improved from 108.01929 to 81.00388, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 25s 161ms/step - loss: 409.7936 - mae: 8.6178 - mse: 409.7936 - val_loss: 81.0039 - val_mae: 6.4488 - val_mse: 81.0039 - learning_rate: 2.0000e-04
# Epoch 4/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 305.1397 - mae: 7.7699 - mse: 305.1397
# Epoch 4: val_loss improved from 81.00388 to 73.83011, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 296ms/step - loss: 390.7081 - mae: 8.0000 - mse: 390.7081 - val_loss: 73.8301 - val_mae: 6.1002 - val_mse: 73.8301 - learning_rate: 2.0000e-04
# Epoch 5/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 465.4508 - mae: 7.9472 - mse: 465.4508
# Epoch 5: val_loss improved from 73.83011 to 73.57261, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 223ms/step - loss: 389.5641 - mae: 7.7975 - mse: 389.5641 - val_loss: 73.5726 - val_mae: 6.4131 - val_mse: 73.5726 - learning_rate: 2.0000e-04
# Epoch 6/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 425.4204 - mae: 7.8385 - mse: 425.4204
# Epoch 6: val_loss improved from 73.57261 to 68.75715, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 25s 166ms/step - loss: 381.0952 - mae: 7.6335 - mse: 381.0952 - val_loss: 68.7571 - val_mae: 5.9765 - val_mse: 68.7571 - learning_rate: 2.0000e-04
# Epoch 7/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 600.0886 - mae: 8.0579 - mse: 600.0886
# Epoch 7: val_loss improved from 68.75715 to 68.74112, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 205ms/step - loss: 370.2989 - mae: 7.3965 - mse: 370.2989 - val_loss: 68.7411 - val_mae: 6.1244 - val_mse: 68.7411 - learning_rate: 2.0000e-04
# Epoch 8/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 278.3708 - mae: 7.1539 - mse: 278.3708
# Epoch 8: val_loss improved from 68.74112 to 66.02660, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 225ms/step - loss: 372.6447 - mae: 7.3798 - mse: 372.6447 - val_loss: 66.0266 - val_mae: 5.8129 - val_mse: 66.0266 - learning_rate: 2.0000e-04
# Epoch 9/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 278.0129 - mae: 7.2557 - mse: 278.0129
# Epoch 9: val_loss improved from 66.02660 to 64.97016, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 225ms/step - loss: 362.1630 - mae: 7.2617 - mse: 362.1630 - val_loss: 64.9702 - val_mae: 5.8505 - val_mse: 64.9702 - learning_rate: 2.0000e-04
# Epoch 10/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 464.3581 - mae: 7.2974 - mse: 464.3581
# Epoch 10: val_loss did not improve from 64.97016
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 29s 179ms/step - loss: 364.6765 - mae: 7.2477 - mse: 364.6765 - val_loss: 67.0282 - val_mae: 6.1555 - val_mse: 67.0282 - learning_rate: 2.0000e-04
# Epoch 11/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 335.4451 - mae: 7.0168 - mse: 335.4451
# Epoch 11: val_loss improved from 64.97016 to 63.57139, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 33s 218ms/step - loss: 357.6229 - mae: 7.1430 - mse: 357.6229 - val_loss: 63.5714 - val_mae: 5.8127 - val_mse: 63.5714 - learning_rate: 2.0000e-04
# Epoch 12/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 353.1832 - mae: 6.7767 - mse: 353.1832
# Epoch 12: val_loss improved from 63.57139 to 60.62298, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 224ms/step - loss: 356.0878 - mae: 6.9688 - mse: 356.0878 - val_loss: 60.6230 - val_mae: 5.6610 - val_mse: 60.6230 - learning_rate: 2.0000e-04
# Epoch 13/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 494.6651 - mae: 7.2227 - mse: 494.6651
# Epoch 13: val_loss did not improve from 60.62298
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 30s 197ms/step - loss: 356.3546 - mae: 7.0602 - mse: 356.3546 - val_loss: 62.0858 - val_mae: 5.7060 - val_mse: 62.0858 - learning_rate: 2.0000e-04
# Epoch 14/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 554.6259 - mae: 7.2383 - mse: 554.6259
# Epoch 14: val_loss improved from 60.62298 to 60.03654, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 36s 237ms/step - loss: 362.2104 - mae: 6.9697 - mse: 362.2104 - val_loss: 60.0365 - val_mae: 5.6306 - val_mse: 60.0365 - learning_rate: 2.0000e-04
# Epoch 15/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 630.7336 - mae: 7.4285 - mse: 630.7336
# Epoch 15: val_loss improved from 60.03654 to 58.27797, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 35s 206ms/step - loss: 349.4893 - mae: 7.0907 - mse: 349.4893 - val_loss: 58.2780 - val_mae: 5.5576 - val_mse: 58.2780 - learning_rate: 2.0000e-04
# Epoch 16/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 480.3416 - mae: 6.9010 - mse: 480.3416
# Epoch 16: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 30s 196ms/step - loss: 353.7599 - mae: 6.9515 - mse: 353.7599 - val_loss: 58.4669 - val_mae: 5.5712 - val_mse: 58.4669 - learning_rate: 2.0000e-04
# Epoch 17/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 199.4017 - mae: 6.6422 - mse: 199.4017
# Epoch 17: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 348.9775 - mae: 6.9363 - mse: 348.9775 - val_loss: 61.0174 - val_mae: 5.5685 - val_mse: 61.0174 - learning_rate: 2.0000e-04
# Epoch 18/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 119.3534 - mae: 6.5829 - mse: 119.3534
# Epoch 18: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 343.7057 - mae: 6.8024 - mse: 343.7057 - val_loss: 64.6255 - val_mae: 5.7863 - val_mse: 64.6255 - learning_rate: 2.0000e-04
# Epoch 19/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 184.5032 - mae: 6.5686 - mse: 184.5032
# Epoch 19: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 347.3359 - mae: 6.7605 - mse: 347.3359 - val_loss: 64.9744 - val_mae: 5.8288 - val_mse: 64.9744 - learning_rate: 2.0000e-04
# Epoch 20/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 668.6633 - mae: 7.1932 - mse: 668.6633
# Epoch 20: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 339.5960 - mae: 6.8893 - mse: 339.5960 - val_loss: 60.3425 - val_mae: 5.7369 - val_mse: 60.3425 - learning_rate: 2.0000e-04
# Epoch 21/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 84.9399 - mae: 6.5009 - mse: 84.9399
# Epoch 21: val_loss did not improve from 58.27797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 334.0360 - mae: 6.6281 - mse: 334.0360 - val_loss: 62.2222 - val_mae: 5.9736 - val_mse: 62.2222 - learning_rate: 2.0000e-04
# Epoch 22/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1149.5186 - mae: 8.7820 - mse: 1149.5186
# Epoch 22: val_loss improved from 58.27797 to 56.86650, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 22: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 36s 235ms/step - loss: 341.2910 - mae: 7.0980 - mse: 341.2910 - val_loss: 56.8665 - val_mae: 5.4759 - val_mse: 56.8665 - learning_rate: 2.0000e-04
# Epoch 23/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 865.0697 - mae: 7.3972 - mse: 865.0697
# Epoch 23: val_loss did not improve from 56.86650
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 29s 192ms/step - loss: 339.8195 - mae: 6.7225 - mse: 339.8195 - val_loss: 59.6691 - val_mae: 5.7168 - val_mse: 59.6691 - learning_rate: 2.0000e-04
# Epoch 24/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 414.7594 - mae: 6.9193 - mse: 414.7594
# Epoch 24: val_loss did not improve from 56.86650
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 330.4646 - mae: 6.6126 - mse: 330.4646 - val_loss: 59.8373 - val_mae: 5.4879 - val_mse: 59.8373 - learning_rate: 2.0000e-04
# Epoch 25/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 374.5092 - mae: 6.5479 - mse: 374.5092
# Epoch 25: val_loss did not improve from 56.86650
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 328.8990 - mae: 6.5366 - mse: 328.8990 - val_loss: 59.7004 - val_mae: 5.4762 - val_mse: 59.7004 - learning_rate: 2.0000e-04
# Epoch 26/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 329.8181 - mae: 6.6512 - mse: 329.8181
# Epoch 26: val_loss improved from 56.86650 to 56.76623, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 26: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 34s 223ms/step - loss: 330.2899 - mae: 6.6169 - mse: 330.2899 - val_loss: 56.7662 - val_mae: 5.4891 - val_mse: 56.7662 - learning_rate: 2.0000e-04
# Epoch 27/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 101.2488 - mae: 5.9622 - mse: 101.2488
# Epoch 27: val_loss did not improve from 56.76623
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 30s 195ms/step - loss: 324.8703 - mae: 6.4095 - mse: 324.8703 - val_loss: 67.6053 - val_mae: 5.8939 - val_mse: 67.6053 - learning_rate: 2.0000e-04
# Epoch 28/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 302.5438 - mae: 6.8499 - mse: 302.5438
# Epoch 28: val_loss did not improve from 56.76623
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 325.7006 - mae: 6.8050 - mse: 325.7006 - val_loss: 59.0542 - val_mae: 5.5423 - val_mse: 59.0542 - learning_rate: 2.0000e-04
# Epoch 29/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 201.0571 - mae: 6.1065 - mse: 201.0571
# Epoch 29: val_loss did not improve from 56.76623
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 311.4012 - mae: 6.5684 - mse: 311.4012 - val_loss: 62.3177 - val_mae: 5.6092 - val_mse: 62.3177 - learning_rate: 2.0000e-04
# Epoch 30/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 518.6955 - mae: 6.9110 - mse: 518.6955
# Epoch 30: val_loss improved from 56.76623 to 55.06705, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
#
# Epoch 30: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage1.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 35s 229ms/step - loss: 309.1914 - mae: 6.4782 - mse: 309.1914 - val_loss: 55.0671 - val_mae: 5.2740 - val_mse: 55.0671 - learning_rate: 2.0000e-04
# Epoch 31/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 236.0101 - mae: 6.1004 - mse: 236.0101
# Epoch 31: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - loss: 309.4141 - mae: 6.4145 - mse: 309.4141 - val_loss: 56.6023 - val_mae: 5.4014 - val_mse: 56.6023 - learning_rate: 2.0000e-04
# Epoch 32/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 107.4633 - mae: 5.7919 - mse: 107.4633
# Epoch 32: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 309.6659 - mae: 6.4287 - mse: 309.6659 - val_loss: 71.6749 - val_mae: 5.9340 - val_mse: 71.6749 - learning_rate: 2.0000e-04
# Epoch 33/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 351.2479 - mae: 6.7617 - mse: 351.2479
# Epoch 33: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 300.5160 - mae: 6.4393 - mse: 300.5160 - val_loss: 59.7999 - val_mae: 5.7293 - val_mse: 59.7999 - learning_rate: 2.0000e-04
# Epoch 34/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 475.4346 - mae: 6.6717 - mse: 475.4346
# Epoch 34: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 303.6673 - mae: 6.4212 - mse: 303.6673 - val_loss: 58.2758 - val_mae: 5.6242 - val_mse: 58.2758 - learning_rate: 2.0000e-04
# Epoch 35/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1002.3046 - mae: 7.5267 - mse: 1002.3046
# Epoch 35: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 298.0345 - mae: 6.4237 - mse: 298.0345 - val_loss: 58.5321 - val_mae: 5.6596 - val_mse: 58.5321 - learning_rate: 2.0000e-04
# Epoch 36/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 181.8428 - mae: 6.1910 - mse: 181.8428
# Epoch 36: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 279.4498 - mae: 6.2617 - mse: 279.4498 - val_loss: 61.4038 - val_mae: 5.5220 - val_mse: 61.4038 - learning_rate: 2.0000e-04
# Epoch 37/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 226.6339 - mae: 6.2097 - mse: 226.6339
# Epoch 37: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 289.3751 - mae: 6.2660 - mse: 289.3751 - val_loss: 62.1223 - val_mae: 5.5725 - val_mse: 62.1223 - learning_rate: 2.0000e-04
# Epoch 38/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 258.7611 - mae: 6.1722 - mse: 258.7611
# Epoch 38: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 290.9236 - mae: 6.3233 - mse: 290.9236 - val_loss: 58.0192 - val_mae: 5.5678 - val_mse: 58.0192 - learning_rate: 2.0000e-04
# Epoch 39/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 109.8637 - mae: 6.1504 - mse: 109.8637
# Epoch 39: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 286.0537 - mae: 6.2534 - mse: 286.0537 - val_loss: 72.6111 - val_mae: 5.9283 - val_mse: 72.6111 - learning_rate: 2.0000e-04
# Epoch 40/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 198.4274 - mae: 5.9893 - mse: 198.4274
# Epoch 40: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 278.3463 - mae: 6.2545 - mse: 278.3463 - val_loss: 60.3835 - val_mae: 5.6281 - val_mse: 60.3835 - learning_rate: 2.0000e-04
# Epoch 41/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 142.3386 - mae: 5.8815 - mse: 142.3386
# Epoch 41: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 270.0348 - mae: 6.1659 - mse: 270.0348 - val_loss: 66.7502 - val_mae: 5.6956 - val_mse: 66.7502 - learning_rate: 2.0000e-04
# Epoch 42/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 117.8198 - mae: 6.0022 - mse: 117.8198
# Epoch 42: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 270.9716 - mae: 6.0561 - mse: 270.9716 - val_loss: 83.5086 - val_mae: 6.2595 - val_mse: 83.5086 - learning_rate: 2.0000e-04
# Epoch 43/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 218.7348 - mae: 6.1947 - mse: 218.7348
# Epoch 43: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 270.8518 - mae: 6.3154 - mse: 270.8518 - val_loss: 60.8032 - val_mae: 5.6099 - val_mse: 60.8032 - learning_rate: 2.0000e-04
# Epoch 44/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 237.9677 - mae: 5.9820 - mse: 237.9677
# Epoch 44: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 235.8129 - mae: 6.0647 - mse: 235.8129 - val_loss: 60.3182 - val_mae: 5.4869 - val_mse: 60.3182 - learning_rate: 2.0000e-04
# Epoch 45/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 180.3480 - mae: 5.8470 - mse: 180.3480
# Epoch 45: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 255.8623 - mae: 6.1509 - mse: 255.8623 - val_loss: 62.8384 - val_mae: 5.5758 - val_mse: 62.8384 - learning_rate: 2.0000e-04
# Epoch 46/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 602.6818 - mae: 6.7546 - mse: 602.6818
# Epoch 46: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 244.6251 - mae: 6.1805 - mse: 244.6251 - val_loss: 60.6595 - val_mae: 5.6663 - val_mse: 60.6595 - learning_rate: 2.0000e-04
# Epoch 47/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 95.5647 - mae: 5.8917 - mse: 95.5647
# Epoch 47: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 243.5816 - mae: 6.1197 - mse: 243.5816 - val_loss: 81.3410 - val_mae: 6.0575 - val_mse: 81.3410 - learning_rate: 2.0000e-04
# Epoch 48/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 166.1376 - mae: 6.0941 - mse: 166.1376
# Epoch 48: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 234.4396 - mae: 6.1644 - mse: 234.4396 - val_loss: 65.1423 - val_mae: 5.6981 - val_mse: 65.1423 - learning_rate: 2.0000e-04
# Epoch 49/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 180.6562 - mae: 5.8436 - mse: 180.6562
# Epoch 49: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 241.8819 - mae: 6.1131 - mse: 241.8819 - val_loss: 62.4951 - val_mae: 5.6315 - val_mse: 62.4951 - learning_rate: 2.0000e-04
# Epoch 50/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 590.9611 - mae: 6.7691 - mse: 590.9611
# Epoch 50: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 247.2516 - mae: 6.1612 - mse: 247.2516 - val_loss: 57.1921 - val_mae: 5.5008 - val_mse: 57.1921 - learning_rate: 2.0000e-04
# Epoch 51/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 327.3841 - mae: 6.0880 - mse: 327.3841
# Epoch 51: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 227.2286 - mae: 6.0440 - mse: 227.2286 - val_loss: 62.7647 - val_mae: 5.6987 - val_mse: 62.7647 - learning_rate: 2.0000e-04
# Epoch 52/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 424.2219 - mae: 6.3802 - mse: 424.2219
# Epoch 52: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 207.1759 - mae: 5.9518 - mse: 207.1759 - val_loss: 62.6581 - val_mae: 5.5636 - val_mse: 62.6581 - learning_rate: 2.0000e-04
# Epoch 53/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 122.8503 - mae: 5.6986 - mse: 122.8503
# Epoch 53: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 205.5417 - mae: 5.9364 - mse: 205.5417 - val_loss: 70.6570 - val_mae: 5.8107 - val_mse: 70.6570 - learning_rate: 2.0000e-04
# Epoch 54/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 484.7313 - mae: 6.6013 - mse: 484.7313
# Epoch 54: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 208.7370 - mae: 5.9815 - mse: 208.7370 - val_loss: 61.9022 - val_mae: 5.6459 - val_mse: 61.9022 - learning_rate: 2.0000e-04
# Epoch 55/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 199.1285 - mae: 5.7485 - mse: 199.1285
# Epoch 55: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 233.6082 - mae: 5.9335 - mse: 233.6082 - val_loss: 57.3750 - val_mae: 5.5297 - val_mse: 57.3750 - learning_rate: 2.0000e-04
# Epoch 56/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 354.9032 - mae: 6.0823 - mse: 354.9032
# Epoch 56: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 209.8790 - mae: 5.9282 - mse: 209.8790 - val_loss: 62.1036 - val_mae: 5.6247 - val_mse: 62.1036 - learning_rate: 2.0000e-04
# Epoch 57/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 504.8317 - mae: 6.5847 - mse: 504.8317
# Epoch 57: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 208.7553 - mae: 5.9043 - mse: 208.7553 - val_loss: 60.1886 - val_mae: 5.7478 - val_mse: 60.1886 - learning_rate: 2.0000e-04
# Epoch 58/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 302.7682 - mae: 6.0063 - mse: 302.7682
# Epoch 58: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 199.9361 - mae: 5.8909 - mse: 199.9361 - val_loss: 73.9679 - val_mae: 6.0385 - val_mse: 73.9679 - learning_rate: 2.0000e-04
# Epoch 59/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 102.2669 - mae: 5.6427 - mse: 102.2669
# Epoch 59: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 193.1501 - mae: 5.8491 - mse: 193.1501 - val_loss: 70.1034 - val_mae: 5.7648 - val_mse: 70.1034 - learning_rate: 2.0000e-04
# Epoch 60/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 103.5163 - mae: 5.6720 - mse: 103.5163
# Epoch 60: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 197.0395 - mae: 5.8264 - mse: 197.0395 - val_loss: 80.6700 - val_mae: 5.9661 - val_mse: 80.6700 - learning_rate: 2.0000e-04
# Epoch 61/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 111.8078 - mae: 5.7343 - mse: 111.8078
# Epoch 61: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 201.1979 - mae: 5.9715 - mse: 201.1979 - val_loss: 73.5846 - val_mae: 5.8305 - val_mse: 73.5846 - learning_rate: 2.0000e-04
# Epoch 62/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 98.5050 - mae: 5.6323 - mse: 98.5050
# Epoch 62: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 182.4630 - mae: 5.8926 - mse: 182.4630 - val_loss: 75.3519 - val_mae: 5.9268 - val_mse: 75.3519 - learning_rate: 2.0000e-04
# Epoch 63/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 131.8619 - mae: 5.6693 - mse: 131.8619
# Epoch 63: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 179.8353 - mae: 5.8734 - mse: 179.8353 - val_loss: 64.8302 - val_mae: 5.7816 - val_mse: 64.8302 - learning_rate: 2.0000e-04
# Epoch 64/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 261.5277 - mae: 5.9593 - mse: 261.5277
# Epoch 64: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 180.2044 - mae: 5.7687 - mse: 180.2044 - val_loss: 58.9601 - val_mae: 5.6125 - val_mse: 58.9601 - learning_rate: 2.0000e-04
# Epoch 65/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 113.6333 - mae: 5.6555 - mse: 113.6333
# Epoch 65: val_loss did not improve from 55.06705
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 157.9363 - mae: 5.6650 - mse: 157.9363 - val_loss: 68.5506 - val_mae: 5.6632 - val_mse: 68.5506 - learning_rate: 2.0000e-04
# Epoch 66/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 236.3794 - mae: 5.8509 - mse: 236.3794
# Epoch 66: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 141.6903 - mae: 5.6445 - mse: 141.6903 - val_loss: 60.0619 - val_mae: 5.4540 - val_mse: 60.0619 - learning_rate: 1.0000e-04
# Epoch 67/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 76.3904 - mae: 5.2587 - mse: 76.3904
# Epoch 67: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 147.8550 - mae: 5.5959 - mse: 147.8550 - val_loss: 57.3023 - val_mae: 5.4028 - val_mse: 57.3023 - learning_rate: 1.0000e-04
# Epoch 68/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 165.2342 - mae: 5.6480 - mse: 165.2342
# Epoch 68: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 147.0225 - mae: 5.6639 - mse: 147.0225 - val_loss: 60.9951 - val_mae: 5.4934 - val_mse: 60.9951 - learning_rate: 1.0000e-04
# Epoch 69/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 136.6838 - mae: 5.4746 - mse: 136.6838
# Epoch 69: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 140.1648 - mae: 5.4872 - mse: 140.1648 - val_loss: 59.4721 - val_mae: 5.4464 - val_mse: 59.4721 - learning_rate: 1.0000e-04
# Epoch 70/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 143.1900 - mae: 5.6026 - mse: 143.1900
# Epoch 70: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 167.2983 - mae: 5.6406 - mse: 167.2983 - val_loss: 59.6155 - val_mae: 5.4949 - val_mse: 59.6155 - learning_rate: 1.0000e-04
# Epoch 71/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 79.7794 - mae: 5.4391 - mse: 79.7794
# Epoch 71: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 119ms/step - loss: 140.0054 - mae: 5.4522 - mse: 140.0054 - val_loss: 60.5965 - val_mae: 5.5865 - val_mse: 60.5965 - learning_rate: 1.0000e-04
# Epoch 72/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 166.8545 - mae: 5.6118 - mse: 166.8545
# Epoch 72: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 156.5848 - mae: 5.5353 - mse: 156.5848 - val_loss: 62.3739 - val_mae: 5.5965 - val_mse: 62.3739 - learning_rate: 1.0000e-04
# Epoch 73/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 68.0903 - mae: 5.2119 - mse: 68.0903
# Epoch 73: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 118.7576 - mae: 5.3673 - mse: 118.7576 - val_loss: 62.3268 - val_mae: 5.6330 - val_mse: 62.3268 - learning_rate: 1.0000e-04
# Epoch 74/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 183.9086 - mae: 5.8233 - mse: 183.9086
# Epoch 74: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 139.0518 - mae: 5.6868 - mse: 139.0518 - val_loss: 61.0047 - val_mae: 5.5470 - val_mse: 61.0047 - learning_rate: 1.0000e-04
# Epoch 75/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 53.3069 - mae: 4.9832 - mse: 53.3069
# Epoch 75: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 123.9899 - mae: 5.3505 - mse: 123.9899 - val_loss: 59.1325 - val_mae: 5.5006 - val_mse: 59.1325 - learning_rate: 1.0000e-04
# Epoch 76/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 104.5919 - mae: 5.2963 - mse: 104.5919
# Epoch 76: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 149.3805 - mae: 5.3998 - mse: 149.3805 - val_loss: 58.3573 - val_mae: 5.4284 - val_mse: 58.3573 - learning_rate: 1.0000e-04
# Epoch 77/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 165.1598 - mae: 5.4280 - mse: 165.1598
# Epoch 77: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 149.9501 - mae: 5.6119 - mse: 149.9501 - val_loss: 58.3365 - val_mae: 5.4489 - val_mse: 58.3365 - learning_rate: 1.0000e-04
# Epoch 78/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 88.1553 - mae: 5.1240 - mse: 88.1553
# Epoch 78: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 141.0488 - mae: 5.3437 - mse: 141.0488 - val_loss: 61.3858 - val_mae: 5.4866 - val_mse: 61.3858 - learning_rate: 1.0000e-04
# Epoch 79/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 95.3593 - mae: 5.3537 - mse: 95.3593
# Epoch 79: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 129.0629 - mae: 5.4405 - mse: 129.0629 - val_loss: 62.4234 - val_mae: 5.5033 - val_mse: 62.4234 - learning_rate: 1.0000e-04
# Epoch 80/100
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 290.4402 - mae: 6.0169 - mse: 290.4402
# Epoch 80: val_loss did not improve from 55.06705
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - loss: 131.1578 - mae: 5.5449 - mse: 131.1578 - val_loss: 61.7478 - val_mae: 5.5377 - val_mse: 61.7478 - learning_rate: 1.0000e-04
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %% [markdown]
# Evaluating stage 1 on test set

# %%
model.load_weights(str(stage1_best_path))

stage1_test_results = model.evaluate(test_dataset, return_dict=True, verbose=1)

print("Stage 1 test results:")
for k, v in stage1_test_results.items():
    print(f"{k}: {v:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 542ms/step - loss: 79.7064 - mae: 6.2187 - mse: 79.7064
# Stage 1 test results:
# loss: 79.7064
# mae: 6.2187
# mse: 79.7064

# %% [markdown]
# Stage 2 (last 30% of the backbone ViT will be unfrozen)

# %%
model.load_weights(str(stage1_best_path))

backbone.trainable = True

num_layers = len(backbone.layers)
freeze_until = int(num_layers * 0.70)

for i, layer in enumerate(backbone.layers):
    layer.trainable = (i >= freeze_until)

print(f"Total backbone layers: {num_layers}")
print(f"Frozen layers:         {freeze_until}")
print(f"Trainable layers:      {num_layers - freeze_until}")

trainable_count = 0
frozen_count = 0
for layer in backbone.layers:
    if layer.trainable:
        trainable_count += 1
    else:
        frozen_count += 1

print("Backbone trainable layers:", trainable_count)
print("Backbone frozen layers:   ", frozen_count)
# Out:
# Total backbone layers: 4
# Frozen layers:         2
# Trainable layers:      2
# Backbone trainable layers: 2
# Backbone frozen layers:    2

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=STAGE2_LR),
    loss="mse",
    metrics=[
        keras.metrics.MeanAbsoluteError(name="mae"),
        keras.metrics.MeanSquaredError(name="mse")
    ],
    jit_compile=False
)

# %%
stage2_best_path = OUTPUT_DIR / "best_model_stage2.weights.h5"

stage2_callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath=str(stage2_best_path),
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
        mode="min",
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=100,
        mode="min",
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=75,
        min_lr=1e-7,
        mode="min",
        verbose=1
    )
]

# %%
history_stage2 = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=STAGE2_EPOCHS,
    callbacks=stage2_callbacks
)
# Out:
# Epoch 1/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 287.1790 - mae: 8.9485 - mse: 287.1790
# Epoch 1: val_loss improved from None to 66.49324, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 140s 474ms/step - loss: 391.5740 - mae: 8.0387 - mse: 391.5740 - val_loss: 66.4932 - val_mae: 5.6260 - val_mse: 66.4932 - learning_rate: 5.0000e-06
# Epoch 2/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - loss: 272.2330 - mae: 6.1130 - mse: 272.2330
# Epoch 2: val_loss improved from 66.49324 to 60.98469, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 113s 734ms/step - loss: 343.5789 - mae: 6.5292 - mse: 343.5789 - val_loss: 60.9847 - val_mae: 5.4960 - val_mse: 60.9847 - learning_rate: 5.0000e-06
# Epoch 3/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - loss: 94.9995 - mae: 4.9075 - mse: 94.9995
# Epoch 3: val_loss did not improve from 60.98469
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 140s 920ms/step - loss: 332.0134 - mae: 6.4909 - mse: 332.0134 - val_loss: 149.0477 - val_mae: 9.0963 - val_mse: 149.0477 - learning_rate: 5.0000e-06
# Epoch 4/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 149.1288 - mae: 6.3946 - mse: 149.1288
# Epoch 4: val_loss did not improve from 60.98469
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 329.6551 - mae: 6.7897 - mse: 329.6551 - val_loss: 96.3289 - val_mae: 6.7068 - val_mse: 96.3289 - learning_rate: 5.0000e-06
# Epoch 5/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 226.6178 - mae: 6.8113 - mse: 226.6178
# Epoch 5: val_loss did not improve from 60.98469
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 242.9344 - mae: 7.2934 - mse: 242.9344 - val_loss: 81.0285 - val_mae: 5.9300 - val_mse: 81.0285 - learning_rate: 5.0000e-06
# Epoch 6/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 302.8373 - mae: 6.2431 - mse: 302.8373
# Epoch 6: val_loss did not improve from 60.98469
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 336.8833 - mae: 6.8417 - mse: 336.8833 - val_loss: 64.5338 - val_mae: 5.7420 - val_mse: 64.5338 - learning_rate: 5.0000e-06
# Epoch 7/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 110.7073 - mae: 5.3476 - mse: 110.7073
# Epoch 7: val_loss did not improve from 60.98469
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 142.1585 - mae: 5.4822 - mse: 142.1585 - val_loss: 64.7366 - val_mae: 5.4790 - val_mse: 64.7366 - learning_rate: 5.0000e-06
# Epoch 8/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 43.5173 - mae: 4.6324 - mse: 43.5173
# Epoch 8: val_loss improved from 60.98469 to 55.63686, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 105s 692ms/step - loss: 48.7468 - mae: 4.6082 - mse: 48.7468 - val_loss: 55.6369 - val_mae: 5.2535 - val_mse: 55.6369 - learning_rate: 5.0000e-06
# Epoch 9/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - loss: 36.8175 - mae: 4.3546 - mse: 36.8175
# Epoch 9: val_loss improved from 55.63686 to 55.00316, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 151s 995ms/step - loss: 35.5839 - mae: 4.2892 - mse: 35.5839 - val_loss: 55.0032 - val_mae: 5.0294 - val_mse: 55.0032 - learning_rate: 5.0000e-06
# Epoch 10/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 31.0068 - mae: 4.0809 - mse: 31.0068
# Epoch 10: val_loss did not improve from 55.00316
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - loss: 35.2376 - mae: 3.9335 - mse: 35.2376 - val_loss: 56.0027 - val_mae: 5.0650 - val_mse: 56.0027 - learning_rate: 5.0000e-06
# Epoch 11/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 38.1022 - mae: 4.0646 - mse: 38.1022
# Epoch 11: val_loss improved from 55.00316 to 53.91724, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 104s 689ms/step - loss: 29.6542 - mae: 3.8807 - mse: 29.6542 - val_loss: 53.9172 - val_mae: 5.0748 - val_mse: 53.9172 - learning_rate: 5.0000e-06
# Epoch 12/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - loss: 34.9793 - mae: 3.4964 - mse: 34.9793
# Epoch 12: val_loss improved from 53.91724 to 47.93269, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - loss: 35.0546 - mae: 3.6093 - mse: 35.0546 - val_loss: 47.9327 - val_mae: 4.8351 - val_mse: 47.9327 - learning_rate: 5.0000e-06
# Epoch 13/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 35.3175 - mae: 3.8030 - mse: 35.3175
# Epoch 13: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - loss: 28.5486 - mae: 3.5906 - mse: 28.5486 - val_loss: 70.5090 - val_mae: 5.6368 - val_mse: 70.5090 - learning_rate: 5.0000e-06
# Epoch 14/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 86.6832 - mae: 3.6025 - mse: 86.6832
# Epoch 14: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - loss: 45.2929 - mae: 3.3694 - mse: 45.2929 - val_loss: 61.6000 - val_mae: 5.3440 - val_mse: 61.6000 - learning_rate: 5.0000e-06
# Epoch 15/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 21.9252 - mae: 3.3434 - mse: 21.9252
# Epoch 15: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 21.9839 - mae: 3.3532 - mse: 21.9839 - val_loss: 54.9732 - val_mae: 4.9508 - val_mse: 54.9732 - learning_rate: 5.0000e-06
# Epoch 16/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 21.1506 - mae: 3.2893 - mse: 21.1506
# Epoch 16: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 20.8401 - mae: 3.2727 - mse: 20.8401 - val_loss: 54.5072 - val_mae: 4.8976 - val_mse: 54.5072 - learning_rate: 5.0000e-06
# Epoch 17/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 19.2168 - mae: 3.1496 - mse: 19.2168
# Epoch 17: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 19.9674 - mae: 3.1402 - mse: 19.9674 - val_loss: 48.5709 - val_mae: 4.8019 - val_mse: 48.5709 - learning_rate: 5.0000e-06
# Epoch 18/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 18.6862 - mae: 3.0584 - mse: 18.6862
# Epoch 18: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 17.5101 - mae: 2.9679 - mse: 17.5101 - val_loss: 50.6838 - val_mae: 4.9979 - val_mse: 50.6838 - learning_rate: 5.0000e-06
# Epoch 19/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 20.0693 - mae: 3.0102 - mse: 20.0693
# Epoch 19: val_loss did not improve from 47.93269
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 23.6649 - mae: 2.9962 - mse: 23.6649 - val_loss: 57.0589 - val_mae: 5.0832 - val_mse: 57.0589 - learning_rate: 5.0000e-06
# Epoch 20/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 26.0182 - mae: 3.7776 - mse: 26.0182
# Epoch 20: val_loss improved from 47.93269 to 46.93423, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 20: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 104s 683ms/step - loss: 21.5489 - mae: 3.3764 - mse: 21.5489 - val_loss: 46.9342 - val_mae: 4.6774 - val_mse: 46.9342 - learning_rate: 5.0000e-06
# Epoch 21/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - loss: 16.2681 - mae: 2.8856 - mse: 16.2681
# Epoch 21: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 140s 926ms/step - loss: 21.4570 - mae: 2.9898 - mse: 21.4570 - val_loss: 48.9111 - val_mae: 4.7025 - val_mse: 48.9111 - learning_rate: 5.0000e-06
# Epoch 22/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 22.6025 - mae: 2.9200 - mse: 22.6025
# Epoch 22: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 36.4470 - mae: 2.8915 - mse: 36.4470 - val_loss: 53.2837 - val_mae: 4.8253 - val_mse: 53.2837 - learning_rate: 5.0000e-06
# Epoch 23/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 21.8146 - mae: 2.8218 - mse: 21.8146
# Epoch 23: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 23.4642 - mae: 2.8842 - mse: 23.4642 - val_loss: 56.1545 - val_mae: 4.9648 - val_mse: 56.1545 - learning_rate: 5.0000e-06
# Epoch 24/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 16.5533 - mae: 2.8294 - mse: 16.5533
# Epoch 24: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 15.8967 - mae: 2.7921 - mse: 15.8967 - val_loss: 58.5021 - val_mae: 5.0162 - val_mse: 58.5021 - learning_rate: 5.0000e-06
# Epoch 25/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 15.5260 - mae: 2.8111 - mse: 15.5260
# Epoch 25: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 15.7390 - mae: 2.7930 - mse: 15.7390 - val_loss: 50.8798 - val_mae: 5.0143 - val_mse: 50.8798 - learning_rate: 5.0000e-06
# Epoch 26/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 26.6712 - mae: 2.9534 - mse: 26.6712
# Epoch 26: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 19.6086 - mae: 2.8502 - mse: 19.6086 - val_loss: 49.7385 - val_mae: 4.6553 - val_mse: 49.7385 - learning_rate: 5.0000e-06
# Epoch 27/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 15.6906 - mae: 2.7755 - mse: 15.6906
# Epoch 27: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 17.5410 - mae: 2.7463 - mse: 17.5410 - val_loss: 49.0555 - val_mae: 4.8004 - val_mse: 49.0555 - learning_rate: 5.0000e-06
# Epoch 28/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 15.4055 - mae: 2.8475 - mse: 15.4055
# Epoch 28: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 14.7912 - mae: 2.7716 - mse: 14.7912 - val_loss: 56.5876 - val_mae: 4.8708 - val_mse: 56.5876 - learning_rate: 5.0000e-06
# Epoch 29/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.9382 - mae: 2.6988 - mse: 14.9382
# Epoch 29: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 14.7090 - mae: 2.6912 - mse: 14.7090 - val_loss: 50.8893 - val_mae: 4.7215 - val_mse: 50.8893 - learning_rate: 5.0000e-06
# Epoch 30/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 16.5256 - mae: 2.6860 - mse: 16.5256
# Epoch 30: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 31.4042 - mae: 2.6699 - mse: 31.4042 - val_loss: 51.9460 - val_mae: 4.8218 - val_mse: 51.9460 - learning_rate: 5.0000e-06
# Epoch 31/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 24.7484 - mae: 2.8735 - mse: 24.7484
# Epoch 31: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 40.5574 - mae: 3.1575 - mse: 40.5574 - val_loss: 58.1507 - val_mae: 4.9185 - val_mse: 58.1507 - learning_rate: 5.0000e-06
# Epoch 32/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 27.5337 - mae: 3.0588 - mse: 27.5337
# Epoch 32: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 24.1509 - mae: 2.8960 - mse: 24.1509 - val_loss: 53.6390 - val_mae: 4.7924 - val_mse: 53.6390 - learning_rate: 5.0000e-06
# Epoch 33/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.6224 - mae: 2.6978 - mse: 14.6224
# Epoch 33: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 16.1782 - mae: 2.7886 - mse: 16.1782 - val_loss: 48.5383 - val_mae: 4.8785 - val_mse: 48.5383 - learning_rate: 5.0000e-06
# Epoch 34/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 14.2817 - mae: 2.7374 - mse: 14.2817
# Epoch 34: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 14.5453 - mae: 2.7519 - mse: 14.5453 - val_loss: 50.0091 - val_mae: 4.7856 - val_mse: 50.0091 - learning_rate: 5.0000e-06
# Epoch 35/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 16.3247 - mae: 2.7252 - mse: 16.3247
# Epoch 35: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 14.8794 - mae: 2.6434 - mse: 14.8794 - val_loss: 51.1604 - val_mae: 4.8977 - val_mse: 51.1604 - learning_rate: 5.0000e-06
# Epoch 36/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.3596 - mae: 2.5887 - mse: 14.3596
# Epoch 36: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 16.2137 - mae: 2.5608 - mse: 16.2137 - val_loss: 55.1925 - val_mae: 4.8615 - val_mse: 55.1925 - learning_rate: 5.0000e-06
# Epoch 37/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 15.9243 - mae: 2.7499 - mse: 15.9243
# Epoch 37: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 19.6497 - mae: 2.7562 - mse: 19.6497 - val_loss: 51.9766 - val_mae: 4.7968 - val_mse: 51.9766 - learning_rate: 5.0000e-06
# Epoch 38/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 34.1138 - mae: 2.9819 - mse: 34.1138
# Epoch 38: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 54.7212 - mae: 3.8000 - mse: 54.7212 - val_loss: 61.8332 - val_mae: 5.3299 - val_mse: 61.8332 - learning_rate: 5.0000e-06
# Epoch 39/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 26.3443 - mae: 3.5904 - mse: 26.3443
# Epoch 39: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 21.5842 - mae: 3.2266 - mse: 21.5842 - val_loss: 67.9992 - val_mae: 5.2976 - val_mse: 67.9992 - learning_rate: 5.0000e-06
# Epoch 40/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 16.6455 - mae: 2.9006 - mse: 16.6455
# Epoch 40: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 15.7661 - mae: 2.7985 - mse: 15.7661 - val_loss: 50.3655 - val_mae: 5.0724 - val_mse: 50.3655 - learning_rate: 5.0000e-06
# Epoch 41/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 12.6471 - mae: 2.5311 - mse: 12.6471
# Epoch 41: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 13.4610 - mae: 2.4789 - mse: 13.4610 - val_loss: 50.1770 - val_mae: 4.9390 - val_mse: 50.1770 - learning_rate: 5.0000e-06
# Epoch 42/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 13.1772 - mae: 2.4964 - mse: 13.1772
# Epoch 42: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 14.4411 - mae: 2.4878 - mse: 14.4411 - val_loss: 50.6871 - val_mae: 4.8382 - val_mse: 50.6871 - learning_rate: 5.0000e-06
# Epoch 43/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 12.2733 - mae: 2.4617 - mse: 12.2733
# Epoch 43: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 13.0085 - mae: 2.4986 - mse: 13.0085 - val_loss: 52.3269 - val_mae: 4.6947 - val_mse: 52.3269 - learning_rate: 5.0000e-06
# Epoch 44/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 18.4560 - mae: 2.4577 - mse: 18.4560
# Epoch 44: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 15.9434 - mae: 2.4485 - mse: 15.9434 - val_loss: 51.0587 - val_mae: 4.7355 - val_mse: 51.0587 - learning_rate: 5.0000e-06
# Epoch 45/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 11.5415 - mae: 2.3818 - mse: 11.5415
# Epoch 45: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 11.9510 - mae: 2.4261 - mse: 11.9510 - val_loss: 51.0144 - val_mae: 4.6701 - val_mse: 51.0144 - learning_rate: 5.0000e-06
# Epoch 46/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.5477 - mae: 2.3377 - mse: 14.5477
# Epoch 46: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 19.3444 - mae: 2.3998 - mse: 19.3444 - val_loss: 49.5554 - val_mae: 4.6700 - val_mse: 49.5554 - learning_rate: 5.0000e-06
# Epoch 47/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 16.7765 - mae: 2.3417 - mse: 16.7765
# Epoch 47: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 25.0420 - mae: 2.3962 - mse: 25.0420 - val_loss: 50.8222 - val_mae: 4.7296 - val_mse: 50.8222 - learning_rate: 5.0000e-06
# Epoch 48/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 13.9805 - mae: 2.3937 - mse: 13.9805
# Epoch 48: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 12.4342 - mae: 2.3935 - mse: 12.4342 - val_loss: 51.1991 - val_mae: 4.6469 - val_mse: 51.1991 - learning_rate: 5.0000e-06
# Epoch 49/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 17.2919 - mae: 2.4568 - mse: 17.2919
# Epoch 49: val_loss did not improve from 46.93423
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 14.5203 - mae: 2.3579 - mse: 14.5203 - val_loss: 55.4098 - val_mae: 4.8449 - val_mse: 55.4098 - learning_rate: 5.0000e-06
# Epoch 50/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 12.2566 - mae: 2.4026 - mse: 12.2566
# Epoch 50: val_loss improved from 46.93423 to 44.72118, saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
#
# Epoch 50: finished saving model to /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/best_model_stage2.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 97s 637ms/step - loss: 11.4473 - mae: 2.3073 - mse: 11.4473 - val_loss: 44.7212 - val_mae: 4.5298 - val_mse: 44.7212 - learning_rate: 5.0000e-06
# Epoch 51/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - loss: 21.0923 - mae: 2.8125 - mse: 21.0923
# Epoch 51: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 140s 925ms/step - loss: 22.9109 - mae: 2.8958 - mse: 22.9109 - val_loss: 64.9242 - val_mae: 5.1415 - val_mse: 64.9242 - learning_rate: 5.0000e-06
# Epoch 52/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 12.7235 - mae: 2.4811 - mse: 12.7235
# Epoch 52: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 13.1294 - mae: 2.5088 - mse: 13.1294 - val_loss: 47.8091 - val_mae: 4.6380 - val_mse: 47.8091 - learning_rate: 5.0000e-06
# Epoch 53/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 25.3440 - mae: 2.6197 - mse: 25.3440
# Epoch 53: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 18.2224 - mae: 2.5473 - mse: 18.2224 - val_loss: 48.2920 - val_mae: 4.6601 - val_mse: 48.2920 - learning_rate: 5.0000e-06
# Epoch 54/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 11.9871 - mae: 2.3143 - mse: 11.9871
# Epoch 54: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 14.4570 - mae: 2.3663 - mse: 14.4570 - val_loss: 50.5518 - val_mae: 4.6794 - val_mse: 50.5518 - learning_rate: 5.0000e-06
# Epoch 55/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 11.7746 - mae: 2.2972 - mse: 11.7746
# Epoch 55: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 12.1614 - mae: 2.3256 - mse: 12.1614 - val_loss: 52.5750 - val_mae: 4.7013 - val_mse: 52.5750 - learning_rate: 5.0000e-06
# Epoch 56/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 12.1457 - mae: 2.4624 - mse: 12.1457
# Epoch 56: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.7715 - mae: 2.3194 - mse: 10.7715 - val_loss: 62.2988 - val_mae: 5.0043 - val_mse: 62.2988 - learning_rate: 5.0000e-06
# Epoch 57/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.8584 - mae: 2.5856 - mse: 14.8584
# Epoch 57: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 12.7565 - mae: 2.3821 - mse: 12.7565 - val_loss: 52.5581 - val_mae: 4.7181 - val_mse: 52.5581 - learning_rate: 5.0000e-06
# Epoch 58/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 9.8007 - mae: 2.1736 - mse: 9.8007
# Epoch 58: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 10.9367 - mae: 2.2247 - mse: 10.9367 - val_loss: 56.7916 - val_mae: 4.8974 - val_mse: 56.7916 - learning_rate: 5.0000e-06
# Epoch 59/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 11.0549 - mae: 2.3002 - mse: 11.0549
# Epoch 59: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 11.4042 - mae: 2.2953 - mse: 11.4042 - val_loss: 51.3105 - val_mae: 4.7416 - val_mse: 51.3105 - learning_rate: 5.0000e-06
# Epoch 60/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 12.2942 - mae: 2.3070 - mse: 12.2942
# Epoch 60: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 12.9961 - mae: 2.2627 - mse: 12.9961 - val_loss: 57.6142 - val_mae: 4.8689 - val_mse: 57.6142 - learning_rate: 5.0000e-06
# Epoch 61/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 15.3087 - mae: 2.4361 - mse: 15.3087
# Epoch 61: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 23.0509 - mae: 2.4771 - mse: 23.0509 - val_loss: 51.8256 - val_mae: 4.6324 - val_mse: 51.8256 - learning_rate: 5.0000e-06
# Epoch 62/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 20.9767 - mae: 2.3297 - mse: 20.9767
# Epoch 62: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 14.1071 - mae: 2.2596 - mse: 14.1071 - val_loss: 59.6341 - val_mae: 4.8375 - val_mse: 59.6341 - learning_rate: 5.0000e-06
# Epoch 63/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.7136 - mae: 2.2275 - mse: 9.7136
# Epoch 63: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.0415 - mae: 2.2052 - mse: 10.0415 - val_loss: 49.2993 - val_mae: 4.6358 - val_mse: 49.2993 - learning_rate: 5.0000e-06
# Epoch 64/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 20.4683 - mae: 2.2669 - mse: 20.4683
# Epoch 64: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 23.3497 - mae: 2.2871 - mse: 23.3497 - val_loss: 50.3285 - val_mae: 4.6197 - val_mse: 50.3285 - learning_rate: 5.0000e-06
# Epoch 65/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.8608 - mae: 2.0783 - mse: 8.8608
# Epoch 65: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.4883 - mae: 2.1397 - mse: 9.4883 - val_loss: 49.6817 - val_mae: 4.5719 - val_mse: 49.6817 - learning_rate: 5.0000e-06
# Epoch 66/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 12.9290 - mae: 2.3499 - mse: 12.9290
# Epoch 66: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 14.6580 - mae: 2.4470 - mse: 14.6580 - val_loss: 53.8470 - val_mae: 4.6451 - val_mse: 53.8470 - learning_rate: 5.0000e-06
# Epoch 67/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 10.6904 - mae: 2.2778 - mse: 10.6904
# Epoch 67: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 11.6058 - mae: 2.2293 - mse: 11.6058 - val_loss: 48.3468 - val_mae: 4.6096 - val_mse: 48.3468 - learning_rate: 5.0000e-06
# Epoch 68/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.8616 - mae: 2.2727 - mse: 10.8616
# Epoch 68: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.3568 - mae: 2.2555 - mse: 10.3568 - val_loss: 49.2589 - val_mae: 4.6150 - val_mse: 49.2589 - learning_rate: 5.0000e-06
# Epoch 69/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.8699 - mae: 2.2262 - mse: 9.8699
# Epoch 69: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 11.1683 - mae: 2.2254 - mse: 11.1683 - val_loss: 50.2687 - val_mae: 4.5736 - val_mse: 50.2687 - learning_rate: 5.0000e-06
# Epoch 70/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 11.7868 - mae: 2.1364 - mse: 11.7868
# Epoch 70: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 11.4254 - mae: 2.1477 - mse: 11.4254 - val_loss: 50.0382 - val_mae: 4.9217 - val_mse: 50.0382 - learning_rate: 5.0000e-06
# Epoch 71/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 11.6756 - mae: 2.3284 - mse: 11.6756
# Epoch 71: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 11.0348 - mae: 2.2025 - mse: 11.0348 - val_loss: 51.0468 - val_mae: 4.6620 - val_mse: 51.0468 - learning_rate: 5.0000e-06
# Epoch 72/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 11.9819 - mae: 2.4145 - mse: 11.9819
# Epoch 72: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 11.5937 - mae: 2.3150 - mse: 11.5937 - val_loss: 59.6407 - val_mae: 4.7898 - val_mse: 59.6407 - learning_rate: 5.0000e-06
# Epoch 73/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 21.5312 - mae: 2.2656 - mse: 21.5312
# Epoch 73: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 16.0624 - mae: 2.2024 - mse: 16.0624 - val_loss: 54.4460 - val_mae: 4.7495 - val_mse: 54.4460 - learning_rate: 5.0000e-06
# Epoch 74/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 12.8775 - mae: 2.1681 - mse: 12.8775
# Epoch 74: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 21.6364 - mae: 2.2616 - mse: 21.6364 - val_loss: 48.0691 - val_mae: 4.6144 - val_mse: 48.0691 - learning_rate: 5.0000e-06
# Epoch 75/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.4262 - mae: 2.1540 - mse: 9.4262
# Epoch 75: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.6022 - mae: 2.2501 - mse: 10.6022 - val_loss: 63.1419 - val_mae: 4.9686 - val_mse: 63.1419 - learning_rate: 5.0000e-06
# Epoch 76/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 12.0773 - mae: 2.3105 - mse: 12.0773
# Epoch 76: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 11.2744 - mae: 2.2636 - mse: 11.2744 - val_loss: 51.9819 - val_mae: 4.6499 - val_mse: 51.9819 - learning_rate: 5.0000e-06
# Epoch 77/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.9131 - mae: 2.1963 - mse: 9.9131
# Epoch 77: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.4640 - mae: 2.1986 - mse: 10.4640 - val_loss: 52.2316 - val_mae: 4.8450 - val_mse: 52.2316 - learning_rate: 5.0000e-06
# Epoch 78/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.3895 - mae: 2.1378 - mse: 10.3895
# Epoch 78: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 10.4585 - mae: 2.0916 - mse: 10.4585 - val_loss: 49.5917 - val_mae: 4.8245 - val_mse: 49.5917 - learning_rate: 5.0000e-06
# Epoch 79/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 12.4443 - mae: 2.2975 - mse: 12.4443
# Epoch 79: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 12.4016 - mae: 2.2169 - mse: 12.4016 - val_loss: 59.5247 - val_mae: 4.8571 - val_mse: 59.5247 - learning_rate: 5.0000e-06
# Epoch 80/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.7882 - mae: 2.1807 - mse: 9.7882
# Epoch 80: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 9.1513 - mae: 2.1061 - mse: 9.1513 - val_loss: 48.6719 - val_mae: 4.6838 - val_mse: 48.6719 - learning_rate: 5.0000e-06
# Epoch 81/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.5037 - mae: 2.0973 - mse: 9.5037
# Epoch 81: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 10.1694 - mae: 2.1550 - mse: 10.1694 - val_loss: 52.9126 - val_mae: 4.6118 - val_mse: 52.9126 - learning_rate: 5.0000e-06
# Epoch 82/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.4250 - mae: 2.0698 - mse: 9.4250
# Epoch 82: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 14.7646 - mae: 2.1501 - mse: 14.7646 - val_loss: 56.8245 - val_mae: 4.7825 - val_mse: 56.8245 - learning_rate: 5.0000e-06
# Epoch 83/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 8.2290 - mae: 2.0428 - mse: 8.2290
# Epoch 83: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 11.3574 - mae: 2.0567 - mse: 11.3574 - val_loss: 53.3458 - val_mae: 4.5591 - val_mse: 53.3458 - learning_rate: 5.0000e-06
# Epoch 84/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.2805 - mae: 2.1103 - mse: 10.2805
# Epoch 84: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 10.1867 - mae: 2.1004 - mse: 10.1867 - val_loss: 48.2901 - val_mae: 4.5442 - val_mse: 48.2901 - learning_rate: 5.0000e-06
# Epoch 85/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 11.1979 - mae: 2.1660 - mse: 11.1979
# Epoch 85: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 9.7033 - mae: 2.0832 - mse: 9.7033 - val_loss: 47.8924 - val_mae: 4.4829 - val_mse: 47.8924 - learning_rate: 5.0000e-06
# Epoch 86/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 9.3693 - mae: 2.1092 - mse: 9.3693
# Epoch 86: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 12.3937 - mae: 2.2219 - mse: 12.3937 - val_loss: 69.6124 - val_mae: 5.3903 - val_mse: 69.6124 - learning_rate: 5.0000e-06
# Epoch 87/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 9.4728 - mae: 2.1355 - mse: 9.4728
# Epoch 87: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 9.7111 - mae: 2.0611 - mse: 9.7111 - val_loss: 48.2850 - val_mae: 4.7910 - val_mse: 48.2850 - learning_rate: 5.0000e-06
# Epoch 88/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.8749 - mae: 2.1038 - mse: 8.8749
# Epoch 88: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.4754 - mae: 2.0369 - mse: 8.4754 - val_loss: 55.0095 - val_mae: 4.6653 - val_mse: 55.0095 - learning_rate: 5.0000e-06
# Epoch 89/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 11.3505 - mae: 2.0522 - mse: 11.3505
# Epoch 89: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.8959 - mae: 2.0356 - mse: 9.8959 - val_loss: 51.3225 - val_mae: 4.5727 - val_mse: 51.3225 - learning_rate: 5.0000e-06
# Epoch 90/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.3269 - mae: 1.9218 - mse: 8.3269
# Epoch 90: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.3978 - mae: 1.9343 - mse: 8.3978 - val_loss: 55.4648 - val_mae: 4.6216 - val_mse: 55.4648 - learning_rate: 5.0000e-06
# Epoch 91/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.4747 - mae: 2.0035 - mse: 9.4747
# Epoch 91: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 12.5823 - mae: 2.0358 - mse: 12.5823 - val_loss: 53.3457 - val_mae: 4.6142 - val_mse: 53.3457 - learning_rate: 5.0000e-06
# Epoch 92/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.2683 - mae: 2.0029 - mse: 8.2683
# Epoch 92: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.3227 - mae: 2.0123 - mse: 8.3227 - val_loss: 56.4344 - val_mae: 4.7374 - val_mse: 56.4344 - learning_rate: 5.0000e-06
# Epoch 93/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.8658 - mae: 2.0565 - mse: 8.8658
# Epoch 93: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.7921 - mae: 2.0115 - mse: 8.7921 - val_loss: 53.0874 - val_mae: 4.6829 - val_mse: 53.0874 - learning_rate: 5.0000e-06
# Epoch 94/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 16.9000 - mae: 2.3449 - mse: 16.9000
# Epoch 94: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 13.8328 - mae: 2.2012 - mse: 13.8328 - val_loss: 49.4846 - val_mae: 4.5907 - val_mse: 49.4846 - learning_rate: 5.0000e-06
# Epoch 95/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 9.5104 - mae: 2.1202 - mse: 9.5104
# Epoch 95: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.7903 - mae: 2.0350 - mse: 8.7903 - val_loss: 54.6846 - val_mae: 4.6471 - val_mse: 54.6846 - learning_rate: 5.0000e-06
# Epoch 96/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 10.2278 - mae: 2.1081 - mse: 10.2278
# Epoch 96: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.3777 - mae: 2.0275 - mse: 9.3777 - val_loss: 50.9244 - val_mae: 4.6387 - val_mse: 50.9244 - learning_rate: 5.0000e-06
# Epoch 97/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 9.4440 - mae: 2.1015 - mse: 9.4440
# Epoch 97: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.0324 - mae: 2.0509 - mse: 9.0324 - val_loss: 51.9635 - val_mae: 4.7836 - val_mse: 51.9635 - learning_rate: 5.0000e-06
# Epoch 98/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.5876 - mae: 1.9608 - mse: 8.5876
# Epoch 98: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 8.8349 - mae: 2.0176 - mse: 8.8349 - val_loss: 58.7838 - val_mae: 4.6767 - val_mse: 58.7838 - learning_rate: 5.0000e-06
# Epoch 99/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 7.7932 - mae: 1.9289 - mse: 7.7932
# Epoch 99: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.5615 - mae: 1.8970 - mse: 7.5615 - val_loss: 51.1638 - val_mae: 4.7373 - val_mse: 51.1638 - learning_rate: 5.0000e-06
# Epoch 100/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 13.0622 - mae: 2.2310 - mse: 13.0622
# Epoch 100: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 13.8954 - mae: 2.0548 - mse: 13.8954 - val_loss: 51.6573 - val_mae: 4.5240 - val_mse: 51.6573 - learning_rate: 5.0000e-06
# Epoch 101/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 6.6131 - mae: 1.7607 - mse: 6.6131
# Epoch 101: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 8.5176 - mae: 1.9226 - mse: 8.5176 - val_loss: 54.3146 - val_mae: 4.6153 - val_mse: 54.3146 - learning_rate: 5.0000e-06
# Epoch 102/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 42.7642 - mae: 2.2132 - mse: 42.7642
# Epoch 102: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 14.0202 - mae: 1.9871 - mse: 14.0202 - val_loss: 58.8012 - val_mae: 4.8169 - val_mse: 58.8012 - learning_rate: 5.0000e-06
# Epoch 103/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.3790 - mae: 2.1188 - mse: 10.3790
# Epoch 103: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 10.4390 - mae: 2.0084 - mse: 10.4390 - val_loss: 49.0559 - val_mae: 4.5575 - val_mse: 49.0559 - learning_rate: 5.0000e-06
# Epoch 104/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 19.7640 - mae: 2.1283 - mse: 19.7640
# Epoch 104: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 10.1982 - mae: 1.9271 - mse: 10.1982 - val_loss: 54.4415 - val_mae: 4.6286 - val_mse: 54.4415 - learning_rate: 5.0000e-06
# Epoch 105/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 11.1211 - mae: 1.8651 - mse: 11.1211
# Epoch 105: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 11.9221 - mae: 1.8697 - mse: 11.9221 - val_loss: 51.4265 - val_mae: 4.5535 - val_mse: 51.4265 - learning_rate: 5.0000e-06
# Epoch 106/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 8.5947 - mae: 1.9990 - mse: 8.5947
# Epoch 106: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.7419 - mae: 1.9171 - mse: 7.7419 - val_loss: 49.9299 - val_mae: 4.5829 - val_mse: 49.9299 - learning_rate: 5.0000e-06
# Epoch 107/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 9.3179 - mae: 1.8884 - mse: 9.3179
# Epoch 107: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 13.2433 - mae: 1.9286 - mse: 13.2433 - val_loss: 54.5343 - val_mae: 4.6580 - val_mse: 54.5343 - learning_rate: 5.0000e-06
# Epoch 108/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 16.9852 - mae: 1.8789 - mse: 16.9852
# Epoch 108: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 12.6668 - mae: 1.9063 - mse: 12.6668 - val_loss: 62.2351 - val_mae: 4.8725 - val_mse: 62.2351 - learning_rate: 5.0000e-06
# Epoch 109/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 15.7463 - mae: 1.9174 - mse: 15.7463
# Epoch 109: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 12.1787 - mae: 1.8910 - mse: 12.1787 - val_loss: 49.0214 - val_mae: 4.5037 - val_mse: 49.0214 - learning_rate: 5.0000e-06
# Epoch 110/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.6161 - mae: 2.0608 - mse: 10.6161
# Epoch 110: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.0888 - mae: 1.9982 - mse: 9.0888 - val_loss: 60.5662 - val_mae: 4.7872 - val_mse: 60.5662 - learning_rate: 5.0000e-06
# Epoch 111/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 15.2370 - mae: 1.9871 - mse: 15.2370
# Epoch 111: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 11.3924 - mae: 1.9800 - mse: 11.3924 - val_loss: 50.6515 - val_mae: 4.7451 - val_mse: 50.6515 - learning_rate: 5.0000e-06
# Epoch 112/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 7.6806 - mae: 1.7911 - mse: 7.6806
# Epoch 112: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.6646 - mae: 1.8222 - mse: 8.6646 - val_loss: 51.1941 - val_mae: 4.5832 - val_mse: 51.1941 - learning_rate: 5.0000e-06
# Epoch 113/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.3513 - mae: 1.9477 - mse: 8.3513
# Epoch 113: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.2876 - mae: 1.9171 - mse: 8.2876 - val_loss: 52.5323 - val_mae: 4.6874 - val_mse: 52.5323 - learning_rate: 5.0000e-06
# Epoch 114/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 6.5302 - mae: 1.7882 - mse: 6.5302
# Epoch 114: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 8.6835 - mae: 1.7783 - mse: 8.6835 - val_loss: 54.6620 - val_mae: 5.2851 - val_mse: 54.6620 - learning_rate: 5.0000e-06
# Epoch 115/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 32.0185 - mae: 2.1762 - mse: 32.0185
# Epoch 115: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 25.8353 - mae: 1.9529 - mse: 25.8353 - val_loss: 56.8188 - val_mae: 4.6980 - val_mse: 56.8188 - learning_rate: 5.0000e-06
# Epoch 116/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 8.2865 - mae: 1.9774 - mse: 8.2865
# Epoch 116: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.4914 - mae: 1.8638 - mse: 7.4914 - val_loss: 52.4628 - val_mae: 4.6438 - val_mse: 52.4628 - learning_rate: 5.0000e-06
# Epoch 117/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 7.2518 - mae: 1.7807 - mse: 7.2518
# Epoch 117: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.1146 - mae: 1.8734 - mse: 8.1146 - val_loss: 62.3846 - val_mae: 4.8280 - val_mse: 62.3846 - learning_rate: 5.0000e-06
# Epoch 118/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.4861 - mae: 1.9727 - mse: 14.4861
# Epoch 118: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 24.0636 - mae: 1.9457 - mse: 24.0636 - val_loss: 53.4771 - val_mae: 4.6819 - val_mse: 53.4771 - learning_rate: 5.0000e-06
# Epoch 119/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 8.5659 - mae: 1.8117 - mse: 8.5659
# Epoch 119: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 12.0291 - mae: 1.8514 - mse: 12.0291 - val_loss: 55.4059 - val_mae: 4.7354 - val_mse: 55.4059 - learning_rate: 5.0000e-06
# Epoch 120/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 14.5190 - mae: 1.7744 - mse: 14.5190
# Epoch 120: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 20.2893 - mae: 1.8427 - mse: 20.2893 - val_loss: 67.0423 - val_mae: 5.1251 - val_mse: 67.0423 - learning_rate: 5.0000e-06
# Epoch 121/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 7.4390 - mae: 1.8570 - mse: 7.4390
# Epoch 121: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.6107 - mae: 1.8532 - mse: 7.6107 - val_loss: 52.7906 - val_mae: 4.6545 - val_mse: 52.7906 - learning_rate: 5.0000e-06
# Epoch 122/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 7.3224 - mae: 1.8650 - mse: 7.3224
# Epoch 122: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.5176 - mae: 1.8536 - mse: 8.5176 - val_loss: 60.6592 - val_mae: 4.8050 - val_mse: 60.6592 - learning_rate: 5.0000e-06
# Epoch 123/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 6.8707 - mae: 1.7937 - mse: 6.8707
# Epoch 123: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.1926 - mae: 1.7750 - mse: 7.1926 - val_loss: 54.2241 - val_mae: 4.6722 - val_mse: 54.2241 - learning_rate: 5.0000e-06
# Epoch 124/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 6.7287 - mae: 1.7534 - mse: 6.7287
# Epoch 124: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 6.6109 - mae: 1.7163 - mse: 6.6109 - val_loss: 54.3572 - val_mae: 4.7625 - val_mse: 54.3572 - learning_rate: 5.0000e-06
# Epoch 125/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 6.2931 - mae: 1.6951 - mse: 6.2931
# Epoch 125: val_loss did not improve from 44.72118
#
# Epoch 125: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 6.3918 - mae: 1.7284 - mse: 6.3918 - val_loss: 55.0586 - val_mae: 4.9246 - val_mse: 55.0586 - learning_rate: 5.0000e-06
# Epoch 126/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 6.9343 - mae: 1.6931 - mse: 6.9343
# Epoch 126: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 7.3812 - mae: 1.6724 - mse: 7.3812 - val_loss: 53.7545 - val_mae: 4.6899 - val_mse: 53.7545 - learning_rate: 2.5000e-06
# Epoch 127/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 6.3553 - mae: 1.7023 - mse: 6.3553
# Epoch 127: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 6.3436 - mae: 1.6736 - mse: 6.3436 - val_loss: 53.9838 - val_mae: 4.6568 - val_mse: 53.9838 - learning_rate: 2.5000e-06
# Epoch 128/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 10.3130 - mae: 1.6818 - mse: 10.3130
# Epoch 128: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 8.7388 - mae: 1.6617 - mse: 8.7388 - val_loss: 55.8369 - val_mae: 4.7045 - val_mse: 55.8369 - learning_rate: 2.5000e-06
# Epoch 129/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 8.8106 - mae: 1.6722 - mse: 8.8106
# Epoch 129: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 9.9417 - mae: 1.6562 - mse: 9.9417 - val_loss: 54.8571 - val_mae: 4.6859 - val_mse: 54.8571 - learning_rate: 2.5000e-06
# Epoch 130/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 6.1232 - mae: 1.6353 - mse: 6.1232
# Epoch 130: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 9.4065 - mae: 1.6429 - mse: 9.4065 - val_loss: 55.7648 - val_mae: 4.6485 - val_mse: 55.7648 - learning_rate: 2.5000e-06
# Epoch 131/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.0723 - mae: 1.4482 - mse: 5.0723
# Epoch 131: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 7.3302 - mae: 1.5300 - mse: 7.3302 - val_loss: 57.9293 - val_mae: 4.7397 - val_mse: 57.9293 - learning_rate: 2.5000e-06
# Epoch 132/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 5.5285 - mae: 1.5753 - mse: 5.5285
# Epoch 132: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 5.8104 - mae: 1.6056 - mse: 5.8104 - val_loss: 54.9377 - val_mae: 4.6392 - val_mse: 54.9377 - learning_rate: 2.5000e-06
# Epoch 133/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 5.4710 - mae: 1.5588 - mse: 5.4710
# Epoch 133: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 5.6476 - mae: 1.5518 - mse: 5.6476 - val_loss: 54.5823 - val_mae: 4.6015 - val_mse: 54.5823 - learning_rate: 2.5000e-06
# Epoch 134/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.6914 - mae: 1.6032 - mse: 5.6914
# Epoch 134: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 6.0293 - mae: 1.6110 - mse: 6.0293 - val_loss: 56.7220 - val_mae: 4.7060 - val_mse: 56.7220 - learning_rate: 2.5000e-06
# Epoch 135/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 6.2056 - mae: 1.6255 - mse: 6.2056
# Epoch 135: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 366ms/step - loss: 9.0016 - mae: 1.6345 - mse: 9.0016 - val_loss: 50.9028 - val_mae: 4.5561 - val_mse: 50.9028 - learning_rate: 2.5000e-06
# Epoch 136/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 6.1952 - mae: 1.5898 - mse: 6.1952
# Epoch 136: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 6.7816 - mae: 1.5931 - mse: 6.7816 - val_loss: 53.0904 - val_mae: 4.6756 - val_mse: 53.0904 - learning_rate: 2.5000e-06
# Epoch 137/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 7.6663 - mae: 1.6720 - mse: 7.6663
# Epoch 137: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 9.2560 - mae: 1.5964 - mse: 9.2560 - val_loss: 54.7008 - val_mae: 4.5922 - val_mse: 54.7008 - learning_rate: 2.5000e-06
# Epoch 138/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 6.1804 - mae: 1.6271 - mse: 6.1804
# Epoch 138: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 6.3558 - mae: 1.6172 - mse: 6.3558 - val_loss: 51.4304 - val_mae: 4.5263 - val_mse: 51.4304 - learning_rate: 2.5000e-06
# Epoch 139/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 7.1042 - mae: 1.5876 - mse: 7.1042
# Epoch 139: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 8.8618 - mae: 1.6304 - mse: 8.8618 - val_loss: 51.6604 - val_mae: 4.7807 - val_mse: 51.6604 - learning_rate: 2.5000e-06
# Epoch 140/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 5.0976 - mae: 1.5287 - mse: 5.0976
# Epoch 140: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 5.4168 - mae: 1.5657 - mse: 5.4168 - val_loss: 55.5014 - val_mae: 4.7306 - val_mse: 55.5014 - learning_rate: 2.5000e-06
# Epoch 141/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.3236 - mae: 1.5828 - mse: 5.3236
# Epoch 141: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 5.6983 - mae: 1.6070 - mse: 5.6983 - val_loss: 53.7179 - val_mae: 4.8246 - val_mse: 53.7179 - learning_rate: 2.5000e-06
# Epoch 142/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 5.0877 - mae: 1.5165 - mse: 5.0877
# Epoch 142: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 6.4501 - mae: 1.5822 - mse: 6.4501 - val_loss: 55.6784 - val_mae: 4.6842 - val_mse: 55.6784 - learning_rate: 2.5000e-06
# Epoch 143/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 5.2989 - mae: 1.5417 - mse: 5.2989
# Epoch 143: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 367ms/step - loss: 5.2757 - mae: 1.5237 - mse: 5.2757 - val_loss: 57.4892 - val_mae: 4.7777 - val_mse: 57.4892 - learning_rate: 2.5000e-06
# Epoch 144/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 11.9456 - mae: 1.7387 - mse: 11.9456
# Epoch 144: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 9.2372 - mae: 1.6037 - mse: 9.2372 - val_loss: 52.2420 - val_mae: 4.7079 - val_mse: 52.2420 - learning_rate: 2.5000e-06
# Epoch 145/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.8965 - mae: 1.5830 - mse: 5.8965
# Epoch 145: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 368ms/step - loss: 6.0447 - mae: 1.5752 - mse: 6.0447 - val_loss: 51.2182 - val_mae: 4.6748 - val_mse: 51.2182 - learning_rate: 2.5000e-06
# Epoch 146/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 5.3817 - mae: 1.5019 - mse: 5.3817
# Epoch 146: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 5.5380 - mae: 1.5516 - mse: 5.5380 - val_loss: 54.1993 - val_mae: 4.7274 - val_mse: 54.1993 - learning_rate: 2.5000e-06
# Epoch 147/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.5601 - mae: 1.5431 - mse: 5.5601
# Epoch 147: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 6.1479 - mae: 1.5887 - mse: 6.1479 - val_loss: 55.0710 - val_mae: 4.6559 - val_mse: 55.0710 - learning_rate: 2.5000e-06
# Epoch 148/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 14.5599 - mae: 1.5567 - mse: 14.5599
# Epoch 148: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 8.9620 - mae: 1.5321 - mse: 8.9620 - val_loss: 53.0861 - val_mae: 4.6156 - val_mse: 53.0861 - learning_rate: 2.5000e-06
# Epoch 149/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 5.3463 - mae: 1.5340 - mse: 5.3463
# Epoch 149: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - loss: 5.1554 - mae: 1.5227 - mse: 5.1554 - val_loss: 54.2945 - val_mae: 4.6145 - val_mse: 54.2945 - learning_rate: 2.5000e-06
# Epoch 150/200
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 5.3151 - mae: 1.5612 - mse: 5.3151
# Epoch 150: val_loss did not improve from 44.72118
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - loss: 5.9051 - mae: 1.5826 - mse: 5.9051 - val_loss: 51.9473 - val_mae: 4.6706 - val_mse: 51.9473 - learning_rate: 2.5000e-06
# Epoch 150: early stopping
# Restoring model weights from the end of the best epoch: 50.

# %% [markdown]
# Evaluating stage 2 on test set

# %%
model.load_weights(str(stage2_best_path))

stage2_test_results = model.evaluate(test_dataset, return_dict=True, verbose=1)

print("Stage 2 test results:")
for k, v in stage2_test_results.items():
    print(f"{k}: {v:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 57.2659 - mae: 4.7653 - mse: 57.2659
# Stage 2 test results:
# loss: 57.2659
# mae: 4.7653
# mse: 57.2659

# %% [markdown]
# Plotting training and validation curves

# %%
def plot_history(history, title_prefix=""):
    hist = history.history
    epochs = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, hist["loss"], label="train_loss")
    plt.plot(epochs, hist["val_loss"], label="val_loss")
    plt.title(f"{title_prefix} Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, hist["mae"], label="train_mae")
    plt.plot(epochs, hist["val_mae"], label="val_mae")
    plt.title(f"{title_prefix} MAE")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_history(history_stage1, "Stage 1")
plot_history(history_stage2, "Stage 2")

# %% [markdown]
# Comparing stage 1 vs stage 2

# %%
comparison_df = pd.DataFrame([
    {
        "stage": "stage_1",
        "test_loss": stage1_test_results.get("loss"),
        "test_mae": stage1_test_results.get("mae"),
        "test_mse": stage1_test_results.get("mse"),
    },
    {
        "stage": "stage_2",
        "test_loss": stage2_test_results.get("loss"),
        "test_mae": stage2_test_results.get("mae"),
        "test_mse": stage2_test_results.get("mse"),
    }
])

display(comparison_df)
comparison_df.to_csv(OUTPUT_DIR / "stage_test_comparison.csv", index=False)
# Out:
#      stage  test_loss  test_mae   test_mse
# 0  stage_1  79.706436  6.218723  79.706436
# 1  stage_2  57.265907  4.765288  57.265907

# %% [markdown]
# Saving test predictions

# %%
model.load_weights(str(stage2_best_path))

test_eval_df = test_df.copy().reset_index(drop=True)

preds = model.predict(test_dataset, verbose=1).reshape(-1)

test_eval_df["prediction"] = preds
test_eval_df["abs_error"] = np.abs(test_eval_df["total_carb"] - test_eval_df["prediction"])
test_eval_df["signed_error"] = test_eval_df["prediction"] - test_eval_df["total_carb"]

pred_csv = OUTPUT_DIR / "test_predictions_stage2.csv"
test_eval_df.to_csv(pred_csv, index=False)

print("Saved:", pred_csv)
display(test_eval_df.head())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(16, 224, 224, 3))
#   warnings.warn(msg)
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step
# Saved: /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/test_predictions_stage2.csv
#            dish_id  total_carb split source_cafe  \
# 0  dish_1556575327      10.618  test       cafe1
# 1  dish_1557861216       0.000  test       cafe1
# 2  dish_1557862345       0.000  test       cafe1
# 3  dish_1557862696       3.850  test       cafe1
# 4  dish_1557862738       0.000  test       cafe1
#
#                                             rgb_path  rgb_exists  rgb_size  \
# 0  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    548259
# 1  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    353804
# 2  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    407501
# 3  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    391780
# 4  /content/drive/MyDrive/Speciale/dataset/nutrit...        True    412017
#
#    prediction  abs_error  signed_error
# 0   12.506059   1.888059      1.888059
# 1    1.025629   1.025629      1.025629
# 2    1.074533   1.074533      1.074533
# 3    3.543763   0.306237     -0.306237
# 4    4.563172   4.563172      4.563172

# %% [markdown]
# Top 10 best and worst dishes

# %%
best_10 = test_eval_df.sort_values("abs_error", ascending=True).head(10)
worst_10 = test_eval_df.sort_values("abs_error", ascending=False).head(10)

print("Top 10 best predictions:")
display(best_10[["dish_id", "total_carb", "prediction", "abs_error", "signed_error"]])

print("Top 10 worst predictions:")
display(worst_10[["dish_id", "total_carb", "prediction", "abs_error", "signed_error"]])

best_10.to_csv(OUTPUT_DIR / "top10_best_predictions_stage2.csv", index=False)
worst_10.to_csv(OUTPUT_DIR / "top10_worst_predictions_stage2.csv", index=False)
# Out:
# Top 10 best predictions:
#              dish_id  total_carb  prediction  abs_error  signed_error
# 54   dish_1558376801    0.795000    0.799759   0.004759      0.004759
# 336  dish_1563909507    8.186116    8.204533   0.018417      0.018417
# 351  dish_1563998323   35.302532   35.326714   0.024182      0.024182
# 289  dish_1562790775    1.519515    1.555516   0.036001      0.036001
# 61   dish_1558461760    2.379000    2.339374   0.039626     -0.039626
# 489  dish_1567007751    9.660000    9.619853   0.040147     -0.040147
# 477  dish_1566850031   25.780001   25.726265   0.053736     -0.053736
# 17   dish_1557937758   18.932001   18.990778   0.058777      0.058777
# 429  dish_1565898158   10.249402   10.319633   0.070231      0.070231
# 122  dish_1559578551    0.322000    0.244739   0.077261     -0.077261
# Top 10 worst predictions:
#              dish_id  total_carb  prediction  abs_error  signed_error
# 178  dish_1560801020   61.690983   27.439901  34.251082    -34.251082
# 179  dish_1560801041   63.245892   29.551977  33.693915    -33.693915
# 149  dish_1560367952   45.956913   13.090037  32.866876    -32.866876
# 177  dish_1560800988   61.249092   28.551718  32.697374    -32.697374
# 150  dish_1560367980   47.243912   16.445541  30.798371    -30.798371
# 247  dish_1562009934   62.243580   33.657471  28.586109    -28.586109
# 313  dish_1563478751   54.133282   25.816860  28.316422    -28.316422
# 318  dish_1563551220   79.790924   52.098049  27.692875    -27.692875
# 446  dish_1566328805   85.054001   57.370705  27.683296    -27.683296
# 325  dish_1563566909   46.750000   20.872572  25.877428    -25.877428

# %% [markdown]
# Saving final model

# %%
model.load_weights(str(stage2_best_path))

final_keras_path = OUTPUT_DIR / "final_model.keras"
model.save(final_keras_path)

export_dir = OUTPUT_DIR / "saved_model_export"
model.export(export_dir)

print("Saved final .keras model to:", final_keras_path)
print("Saved exported model to:", export_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# Saved artifact at '/content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/saved_model_export'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): Dict[['rgb_input', TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='rgb_input')]]
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136605687866064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136605687866832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136605687866448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634353104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634354448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634354832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634353872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634353488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634352720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634356176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634356368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634354064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634354640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634354256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634357136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634352912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634346000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634358096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634357904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634357712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634356752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634357328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634358864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634356560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634359248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634359632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634358288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634359056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634356944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634359440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634355024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634357520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634358672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634358480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658672912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658672720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658672528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658673488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658673296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658673104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600658671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657265680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657265872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657266448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657264912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657265296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657266064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657266640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657268176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657264720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657268560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657268368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657268944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657268752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657269136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657265104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657266256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657266832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657265488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657270672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657270480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657270096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657271632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657269328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657271824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657271056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657269712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657270288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657267792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657274320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657274128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657273936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657273552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657275088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657272784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657275472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657275664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657274512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657273168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657273744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657271248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657276432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657278544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657276240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657278928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657276624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657280272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657278160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657280848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657274704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657278352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657280464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655773968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655774544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655775504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655774736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600657280080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655774160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655775312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655773776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655776464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655774928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655775120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655777424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655777232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655777040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655776080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655776656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655775888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655779152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655777616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655774352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655776272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655779920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655776848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655775696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655780880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655780688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655780496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655779536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655780112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655781648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655779344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655781840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655781072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655779728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655783376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655780304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655777808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655784336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655784144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655783952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655783568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655785104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655782800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655785488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655785296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655785872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655785680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655786064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655784528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655781456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655783184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655786832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655783760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655781264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655786448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655788560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655786256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655788752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655789328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655789136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655789520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655784912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655788368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655787216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655788176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655789904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655784720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600655789712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656396560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656397328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656398288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656397520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656398672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656398480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656399056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656398864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656399248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656396752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656396944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656397712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656396368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656397136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656399632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656401744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656399440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656402128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656401936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656402512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656402320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656402704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656401168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656398096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656399824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656403472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656400400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656397904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656404432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656404240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656404048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656403088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656403664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656402896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656406160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656404624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656401552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656403280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656406928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656403856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656401360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656407888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656407696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656407504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656406544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656407120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656408656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656406352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656409040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656408848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656409424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656409232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656409616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656408080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656405008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656406736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656407312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656404816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656411344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656411152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656412112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656412496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656411728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656411920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656409808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656408272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656408464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656412304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656411536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600656410768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654972112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654971920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654973072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654972880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654972688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654972304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654973840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654971728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654971152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654976528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654976336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654976144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654975184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654975760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654977296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654974992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654977680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654977488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654978064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654977872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654976720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654973648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654975376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654975952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654973456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654978640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654980752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654978448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654981520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654981328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654980176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654982480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654979408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654976912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654983440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600634353296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654983056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136605687867024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136605687869136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654982288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654984208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136600654983632: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved final .keras model to: /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/final_model.keras
# Saved exported model to: /content/drive/MyDrive/Speciale/Models/Model_3_V3_DINO_RGB_only/saved_model_export
