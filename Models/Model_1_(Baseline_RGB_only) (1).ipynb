# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Libraries needed

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from tensorflow import keras
from tensorflow.keras import layers
from huggingface_hub import create_repo, upload_folder

# %% [markdown]
# Path to dataset and Meta data

# %%
DATASET_DIR = Path("/content/drive/MyDrive/Speciale/dataset/nutrition5k_compactV3")

# Metadata CSV created from your local preparation script
METADATA_CSV = Path("/content/drive/MyDrive/Speciale/dataset/prepared_overhead_rgb_dataset/dish_carb_split_metadata.csv")

# Output folder for this model
OUTPUT_DIR = Path("/content/drive/MyDrive/Speciale/Models/Model_2_efficientnetv2b0_rgb_pretrained")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Loading dataset

# %%
df = pd.read_csv(METADATA_CSV)

print(df.head())
print(df["split"].value_counts())
# Out:
#            dish_id  total_carb split source_cafe
# 0  dish_1556575327      10.618  test       cafe1
# 1  dish_1557861216       0.000  test       cafe1
# 2  dish_1557862345       0.000  test       cafe1
# 3  dish_1557862696       3.850  test       cafe1
# 4  dish_1557862738       0.000  test       cafe1
# split
# train    2421
# test      507
# val       334
# Name: count, dtype: int64

# %%
df["image_path"] = df["dish_id"].apply(
    lambda d: str(DATASET_DIR / d / "overhead" / "rgb.png")
)

df["image_exists"] = df["image_path"].apply(lambda p: Path(p).exists())

print("Missing images:", (~df["image_exists"]).sum())

df = df[df["image_exists"]].copy()

print(df["split"].value_counts())
print(df.head())
# Out:
# Missing images: 0
# split
# train    2421
# test      507
# val       334
# Name: count, dtype: int64
#            dish_id  total_carb split source_cafe  \
# 0  dish_1556575327      10.618  test       cafe1
# 1  dish_1557861216       0.000  test       cafe1
# 2  dish_1557862345       0.000  test       cafe1
# 3  dish_1557862696       3.850  test       cafe1
# 4  dish_1557862738       0.000  test       cafe1
#
#                                           image_path  image_exists
# 0  /content/drive/MyDrive/Speciale/dataset/nutrit...          True
# 1  /content/drive/MyDrive/Speciale/dataset/nutrit...          True
# 2  /content/drive/MyDrive/Speciale/dataset/nutrit...          True
# 3  /content/drive/MyDrive/Speciale/dataset/nutrit...          True
# 4  /content/drive/MyDrive/Speciale/dataset/nutrit...          True

# %% [markdown]
# Creating Training / Validation and testing split

# %%
train_df = df[df["split"] == "train"].copy()
val_df   = df[df["split"] == "val"].copy()
test_df  = df[df["split"] == "test"].copy()

print("Train:", len(train_df))
print("Val:  ", len(val_df))
print("Test: ", len(test_df))
# Out:
# Train: 2421
# Val:   334
# Test:  507

# %% [markdown]
# Parameters

# %%
IMG_HEIGHT = 640
IMG_WIDTH  = 480
BATCH_SIZE = 16
AUTOTUNE   = tf.data.AUTOTUNE
EPOCHS     = 300

# %% [markdown]
# Data loading

# %%
def load_image_and_label(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32)   # keep in [0,255]
    label = tf.cast(label, tf.float32)
    return image, label


def make_dataset(dataframe, batch_size=8, shuffle=False):
    image_paths = dataframe["image_path"].values
    labels = dataframe["total_carb"].values.astype("float32")

    ds = tf.data.Dataset.from_tensor_slices((image_paths, labels))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe), seed=42)

    ds = ds.map(load_image_and_label, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds


train_dataset = make_dataset(train_df, batch_size=BATCH_SIZE, shuffle=True)
validation_dataset = make_dataset(val_df, batch_size=BATCH_SIZE, shuffle=False)
test_dataset = make_dataset(test_df, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Model architecture

# %%
from tensorflow.keras.applications import EfficientNetV2B0

base_model = EfficientNetV2B0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)
)

# First stage: freeze pretrained backbone
base_model.trainable = False

inputs = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3), name="rgb_input")

# Forward pass through pretrained backbone
x = base_model(inputs, training=False)

# Head for regression
x = layers.GlobalAveragePooling2D(name="gap")(x)
x = layers.Dropout(0.3, name="dropout")(x)
x = layers.Dense(128, activation="relu", name="dense_128")(x)
x = layers.Dropout(0.2, name="dropout_2")(x)
outputs = layers.Dense(1, activation="linear", name="carb_output")(x)

model = keras.Model(inputs, outputs, name="efficientnetv2b0_rgb_pretrained_carb_regression")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "efficientnetv2b0_rgb_pretrained_carb_regression"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rgb_input (InputLayer)          │ (None, 640, 480, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 20, 15, 1280)   │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_128 (Dense)               │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ carb_output (Dense)             │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,083,409 (23.21 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 5,919,312 (22.58 MB)

# %% [markdown]
# The model will be based on the EfficientNetV2B0 as the pretrained model due to that model being proven to perform the best on this dataset. There is a regression head trained on top of this model which will be based on the training data here.

# %% [markdown]
# Compile

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="mse",
    metrics=[
        keras.metrics.MeanAbsoluteError(name="mae"),
        keras.metrics.MeanSquaredError(name="mse")
    ]
)

# %% [markdown]
# Callbacks

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath=str(OUTPUT_DIR / "best_model.keras"),
        monitor="val_loss",
        save_best_only=True,
        mode="min",
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=150,
        mode="min",
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=125,
        min_lr=1e-6,
        mode="min",
        verbose=1
    )
]

# %% [markdown]
# Train

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 424.8573 - mae: 12.6603 - mse: 424.8573
# Epoch 1: val_loss improved from None to 144.66165, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 609s 4s/step - loss: 488.3886 - mae: 11.3691 - mse: 488.3886 - val_loss: 144.6617 - val_mae: 8.7171 - val_mse: 144.6617 - learning_rate: 0.0010
# Epoch 2/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 401.3943 - mae: 9.4779 - mse: 401.3943
# Epoch 2: val_loss improved from 144.66165 to 132.21892, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 264ms/step - loss: 431.5184 - mae: 9.4117 - mse: 431.5184 - val_loss: 132.2189 - val_mae: 8.9001 - val_mse: 132.2189 - learning_rate: 0.0010
# Epoch 3/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 144.7318 - mae: 8.1716 - mse: 144.7318
# Epoch 3: val_loss improved from 132.21892 to 117.97112, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 270ms/step - loss: 414.6193 - mae: 8.6567 - mse: 414.6193 - val_loss: 117.9711 - val_mae: 8.4498 - val_mse: 117.9711 - learning_rate: 0.0010
# Epoch 4/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 210.9815 - mae: 8.2699 - mse: 210.9815
# Epoch 4: val_loss improved from 117.97112 to 102.69593, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 402.5298 - mae: 8.4076 - mse: 402.5298 - val_loss: 102.6959 - val_mae: 7.5051 - val_mse: 102.6959 - learning_rate: 0.0010
# Epoch 5/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 306.0452 - mae: 7.7345 - mse: 306.0452
# Epoch 5: val_loss improved from 102.69593 to 95.39449, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 253ms/step - loss: 394.3789 - mae: 8.0370 - mse: 394.3789 - val_loss: 95.3945 - val_mae: 6.9687 - val_mse: 95.3945 - learning_rate: 0.0010
# Epoch 6/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 468.7812 - mae: 8.2776 - mse: 468.7812
# Epoch 6: val_loss did not improve from 95.39449
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 246ms/step - loss: 396.8776 - mae: 8.2043 - mse: 396.8776 - val_loss: 96.8090 - val_mae: 7.6527 - val_mse: 96.8090 - learning_rate: 0.0010
# Epoch 7/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 434.7044 - mae: 8.0565 - mse: 434.7044
# Epoch 7: val_loss improved from 95.39449 to 90.33907, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 255ms/step - loss: 392.0342 - mae: 8.0316 - mse: 392.0342 - val_loss: 90.3391 - val_mae: 7.1158 - val_mse: 90.3391 - learning_rate: 0.0010
# Epoch 8/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 618.7226 - mae: 8.4408 - mse: 618.7226
# Epoch 8: val_loss improved from 90.33907 to 86.89409, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 269ms/step - loss: 386.1564 - mae: 7.8045 - mse: 386.1564 - val_loss: 86.8941 - val_mae: 6.9041 - val_mse: 86.8941 - learning_rate: 0.0010
# Epoch 9/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 295.1333 - mae: 7.6689 - mse: 295.1333
# Epoch 9: val_loss did not improve from 86.89409
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 388.0473 - mae: 7.9430 - mse: 388.0473 - val_loss: 88.1329 - val_mae: 7.0832 - val_mse: 88.1329 - learning_rate: 0.0010
# Epoch 10/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 299.2784 - mae: 7.8142 - mse: 299.2784
# Epoch 10: val_loss did not improve from 86.89409
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 287ms/step - loss: 386.8295 - mae: 7.8232 - mse: 386.8295 - val_loss: 95.1379 - val_mae: 7.7047 - val_mse: 95.1379 - learning_rate: 0.0010
# Epoch 11/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 473.4544 - mae: 7.6381 - mse: 473.4544
# Epoch 11: val_loss improved from 86.89409 to 85.83544, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 293ms/step - loss: 373.3268 - mae: 7.5781 - mse: 373.3268 - val_loss: 85.8354 - val_mae: 7.2237 - val_mse: 85.8354 - learning_rate: 0.0010
# Epoch 12/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 343.6629 - mae: 7.2359 - mse: 343.6629
# Epoch 12: val_loss improved from 85.83544 to 79.59255, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 269ms/step - loss: 374.4312 - mae: 7.6935 - mse: 374.4312 - val_loss: 79.5926 - val_mae: 6.7042 - val_mse: 79.5926 - learning_rate: 0.0010
# Epoch 13/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 379.9827 - mae: 7.6455 - mse: 379.9827
# Epoch 13: val_loss improved from 79.59255 to 78.51401, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 257ms/step - loss: 378.8861 - mae: 7.6535 - mse: 378.8861 - val_loss: 78.5140 - val_mae: 6.6860 - val_mse: 78.5140 - learning_rate: 0.0010
# Epoch 14/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 510.4613 - mae: 7.6293 - mse: 510.4613
# Epoch 14: val_loss did not improve from 78.51401
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 373.6658 - mae: 7.5709 - mse: 373.6658 - val_loss: 80.4093 - val_mae: 6.7414 - val_mse: 80.4093 - learning_rate: 0.0010
# Epoch 15/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 559.1249 - mae: 7.7075 - mse: 559.1249
# Epoch 15: val_loss did not improve from 78.51401
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 265ms/step - loss: 372.3576 - mae: 7.5360 - mse: 372.3576 - val_loss: 80.2240 - val_mae: 6.6769 - val_mse: 80.2240 - learning_rate: 0.0010
# Epoch 16/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 664.8435 - mae: 7.9237 - mse: 664.8435
# Epoch 16: val_loss improved from 78.51401 to 78.46488, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 46s 296ms/step - loss: 374.3526 - mae: 7.5906 - mse: 374.3526 - val_loss: 78.4649 - val_mae: 6.5211 - val_mse: 78.4649 - learning_rate: 0.0010
# Epoch 17/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 496.6218 - mae: 7.4061 - mse: 496.6218
# Epoch 17: val_loss improved from 78.46488 to 76.92699, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - loss: 370.9949 - mae: 7.5194 - mse: 370.9949 - val_loss: 76.9270 - val_mae: 6.5896 - val_mse: 76.9270 - learning_rate: 0.0010
# Epoch 18/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 220.0921 - mae: 7.2553 - mse: 220.0921
# Epoch 18: val_loss did not improve from 76.92699
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 295ms/step - loss: 371.3257 - mae: 7.6010 - mse: 371.3257 - val_loss: 82.7385 - val_mae: 6.5354 - val_mse: 82.7385 - learning_rate: 0.0010
# Epoch 19/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 129.4355 - mae: 6.9867 - mse: 129.4355
# Epoch 19: val_loss did not improve from 76.92699
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 291ms/step - loss: 364.8523 - mae: 7.2921 - mse: 364.8523 - val_loss: 88.3483 - val_mae: 6.9767 - val_mse: 88.3483 - learning_rate: 0.0010
# Epoch 20/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 203.1174 - mae: 7.3826 - mse: 203.1174
# Epoch 20: val_loss did not improve from 76.92699
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 365.6207 - mae: 7.4253 - mse: 365.6207 - val_loss: 78.7121 - val_mae: 6.6174 - val_mse: 78.7121 - learning_rate: 0.0010
# Epoch 21/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 677.6267 - mae: 7.7120 - mse: 677.6267
# Epoch 21: val_loss improved from 76.92699 to 75.97765, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 352.0349 - mae: 7.3844 - mse: 352.0349 - val_loss: 75.9777 - val_mae: 6.6124 - val_mse: 75.9777 - learning_rate: 0.0010
# Epoch 22/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 96.3541 - mae: 6.9494 - mse: 96.3541
# Epoch 22: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 248ms/step - loss: 359.4091 - mae: 7.3381 - mse: 359.4091 - val_loss: 90.4769 - val_mae: 7.4938 - val_mse: 90.4769 - learning_rate: 0.0010
# Epoch 23/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 1179.1200 - mae: 9.5278 - mse: 1179.1200
# Epoch 23: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 256ms/step - loss: 359.7374 - mae: 7.7733 - mse: 359.7374 - val_loss: 78.6321 - val_mae: 6.5922 - val_mse: 78.6321 - learning_rate: 0.0010
# Epoch 24/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 864.8845 - mae: 7.9840 - mse: 864.8845
# Epoch 24: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 251ms/step - loss: 349.0810 - mae: 7.2833 - mse: 349.0810 - val_loss: 78.9660 - val_mae: 6.6661 - val_mse: 78.9660 - learning_rate: 0.0010
# Epoch 25/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 429.8731 - mae: 7.5046 - mse: 429.8731
# Epoch 25: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 287ms/step - loss: 345.2136 - mae: 7.2408 - mse: 345.2136 - val_loss: 79.1785 - val_mae: 6.4278 - val_mse: 79.1785 - learning_rate: 0.0010
# Epoch 26/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 421.3782 - mae: 7.5264 - mse: 421.3782
# Epoch 26: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 372.0941 - mae: 7.5704 - mse: 372.0941 - val_loss: 81.7101 - val_mae: 6.5400 - val_mse: 81.7101 - learning_rate: 0.0010
# Epoch 27/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 352.5490 - mae: 7.3340 - mse: 352.5490
# Epoch 27: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 252ms/step - loss: 354.6071 - mae: 7.3472 - mse: 354.6071 - val_loss: 76.9312 - val_mae: 6.6613 - val_mse: 76.9312 - learning_rate: 0.0010
# Epoch 28/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 122.7658 - mae: 6.8904 - mse: 122.7658
# Epoch 28: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 242ms/step - loss: 352.0515 - mae: 7.2658 - mse: 352.0515 - val_loss: 96.9754 - val_mae: 7.1722 - val_mse: 96.9754 - learning_rate: 0.0010
# Epoch 29/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 330.7671 - mae: 7.5467 - mse: 330.7671
# Epoch 29: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 351.0969 - mae: 7.3992 - mse: 351.0969 - val_loss: 76.2001 - val_mae: 6.4439 - val_mse: 76.2001 - learning_rate: 0.0010
# Epoch 30/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 227.1360 - mae: 6.8176 - mse: 227.1360
# Epoch 30: val_loss did not improve from 75.97765
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 287ms/step - loss: 341.7712 - mae: 7.1875 - mse: 341.7712 - val_loss: 83.2010 - val_mae: 6.5383 - val_mse: 83.2010 - learning_rate: 0.0010
# Epoch 31/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 557.2392 - mae: 7.7881 - mse: 557.2392
# Epoch 31: val_loss improved from 75.97765 to 75.40257, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - loss: 338.4888 - mae: 7.2883 - mse: 338.4888 - val_loss: 75.4026 - val_mae: 6.4717 - val_mse: 75.4026 - learning_rate: 0.0010
# Epoch 32/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 271.0944 - mae: 7.0686 - mse: 271.0944
# Epoch 32: val_loss did not improve from 75.40257
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 249ms/step - loss: 345.6758 - mae: 7.1912 - mse: 345.6758 - val_loss: 83.4695 - val_mae: 6.6174 - val_mse: 83.4695 - learning_rate: 0.0010
# Epoch 33/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 130.2366 - mae: 6.6113 - mse: 130.2366
# Epoch 33: val_loss did not improve from 75.40257
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - loss: 343.0559 - mae: 7.0414 - mse: 343.0559 - val_loss: 98.0966 - val_mae: 7.0948 - val_mse: 98.0966 - learning_rate: 0.0010
# Epoch 34/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 399.4756 - mae: 7.7248 - mse: 399.4756
# Epoch 34: val_loss did not improve from 75.40257
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - loss: 344.2408 - mae: 7.4441 - mse: 344.2408 - val_loss: 75.9379 - val_mae: 6.3730 - val_mse: 75.9379 - learning_rate: 0.0010
# Epoch 35/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 488.6713 - mae: 7.3654 - mse: 488.6713
# Epoch 35: val_loss improved from 75.40257 to 73.24123, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 291ms/step - loss: 319.2385 - mae: 7.1583 - mse: 319.2385 - val_loss: 73.2412 - val_mae: 6.4218 - val_mse: 73.2412 - learning_rate: 0.0010
# Epoch 36/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 1069.1644 - mae: 8.2713 - mse: 1069.1644
# Epoch 36: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 331.0558 - mae: 7.2731 - mse: 331.0558 - val_loss: 73.5101 - val_mae: 6.4279 - val_mse: 73.5101 - learning_rate: 0.0010
# Epoch 37/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 209.1710 - mae: 6.7609 - mse: 209.1710
# Epoch 37: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 283ms/step - loss: 322.7893 - mae: 7.1206 - mse: 322.7893 - val_loss: 78.7270 - val_mae: 6.4138 - val_mse: 78.7270 - learning_rate: 0.0010
# Epoch 38/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 252.3349 - mae: 6.7242 - mse: 252.3349
# Epoch 38: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 322.1779 - mae: 6.9416 - mse: 322.1779 - val_loss: 81.2494 - val_mae: 6.6602 - val_mse: 81.2494 - learning_rate: 0.0010
# Epoch 39/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 289.2706 - mae: 6.8273 - mse: 289.2706
# Epoch 39: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 37s 242ms/step - loss: 318.0627 - mae: 6.8667 - mse: 318.0627 - val_loss: 75.5655 - val_mae: 6.3520 - val_mse: 75.5655 - learning_rate: 0.0010
# Epoch 40/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 129.6346 - mae: 6.6741 - mse: 129.6346
# Epoch 40: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - loss: 328.7371 - mae: 7.0559 - mse: 328.7371 - val_loss: 106.1938 - val_mae: 7.1359 - val_mse: 106.1938 - learning_rate: 0.0010
# Epoch 41/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 225.1013 - mae: 6.5450 - mse: 225.1013
# Epoch 41: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - loss: 319.3641 - mae: 6.9891 - mse: 319.3641 - val_loss: 81.6520 - val_mae: 6.7049 - val_mse: 81.6520 - learning_rate: 0.0010
# Epoch 42/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 165.8732 - mae: 6.7079 - mse: 165.8732
# Epoch 42: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 255ms/step - loss: 303.5883 - mae: 7.0876 - mse: 303.5883 - val_loss: 96.5525 - val_mae: 6.9343 - val_mse: 96.5525 - learning_rate: 0.0010
# Epoch 43/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 138.5957 - mae: 6.7321 - mse: 138.5957
# Epoch 43: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 282ms/step - loss: 304.7387 - mae: 6.9102 - mse: 304.7387 - val_loss: 129.5882 - val_mae: 7.7514 - val_mse: 129.5882 - learning_rate: 0.0010
# Epoch 44/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 278.2324 - mae: 6.9809 - mse: 278.2324
# Epoch 44: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 342.7776 - mae: 7.0760 - mse: 342.7776 - val_loss: 85.7617 - val_mae: 6.4541 - val_mse: 85.7617 - learning_rate: 0.0010
# Epoch 45/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 300.4309 - mae: 6.8837 - mse: 300.4309
# Epoch 45: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 300.9651 - mae: 7.0351 - mse: 300.9651 - val_loss: 83.6944 - val_mae: 6.4996 - val_mse: 83.6944 - learning_rate: 0.0010
# Epoch 46/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 216.4325 - mae: 6.5567 - mse: 216.4325
# Epoch 46: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - loss: 313.2935 - mae: 7.0480 - mse: 313.2935 - val_loss: 83.5576 - val_mae: 6.3928 - val_mse: 83.5576 - learning_rate: 0.0010
# Epoch 47/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 731.5712 - mae: 7.7354 - mse: 731.5712
# Epoch 47: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 243ms/step - loss: 299.0217 - mae: 7.0166 - mse: 299.0217 - val_loss: 90.5478 - val_mae: 7.3836 - val_mse: 90.5478 - learning_rate: 0.0010
# Epoch 48/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 116.4136 - mae: 6.7045 - mse: 116.4136
# Epoch 48: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 255ms/step - loss: 300.5309 - mae: 6.8836 - mse: 300.5309 - val_loss: 108.0283 - val_mae: 7.0577 - val_mse: 108.0283 - learning_rate: 0.0010
# Epoch 49/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 207.1340 - mae: 6.8245 - mse: 207.1340
# Epoch 49: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 304.4354 - mae: 7.0047 - mse: 304.4354 - val_loss: 89.4867 - val_mae: 6.9137 - val_mse: 89.4867 - learning_rate: 0.0010
# Epoch 50/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 217.0285 - mae: 6.6389 - mse: 217.0285
# Epoch 50: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 293ms/step - loss: 284.3347 - mae: 6.8780 - mse: 284.3347 - val_loss: 92.2530 - val_mae: 6.8069 - val_mse: 92.2530 - learning_rate: 0.0010
# Epoch 51/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 604.1625 - mae: 7.3111 - mse: 604.1625
# Epoch 51: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 260.5370 - mae: 6.8494 - mse: 260.5370 - val_loss: 82.8937 - val_mae: 6.4287 - val_mse: 82.8937 - learning_rate: 0.0010
# Epoch 52/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 415.2674 - mae: 6.9203 - mse: 415.2674
# Epoch 52: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 247ms/step - loss: 289.9122 - mae: 6.7981 - mse: 289.9122 - val_loss: 83.3650 - val_mae: 6.7016 - val_mse: 83.3650 - learning_rate: 0.0010
# Epoch 53/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 593.9192 - mae: 7.1508 - mse: 593.9192
# Epoch 53: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - loss: 286.6877 - mae: 6.7615 - mse: 286.6877 - val_loss: 88.0790 - val_mae: 6.5092 - val_mse: 88.0790 - learning_rate: 0.0010
# Epoch 54/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 175.8629 - mae: 6.6617 - mse: 175.8629
# Epoch 54: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 290ms/step - loss: 291.5070 - mae: 6.6645 - mse: 291.5070 - val_loss: 106.4849 - val_mae: 6.9845 - val_mse: 106.4849 - learning_rate: 0.0010
# Epoch 55/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 599.8025 - mae: 7.6202 - mse: 599.8025
# Epoch 55: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 287ms/step - loss: 262.9351 - mae: 6.8864 - mse: 262.9351 - val_loss: 82.5378 - val_mae: 6.5788 - val_mse: 82.5378 - learning_rate: 0.0010
# Epoch 56/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 255.5327 - mae: 6.7292 - mse: 255.5327
# Epoch 56: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - loss: 282.1992 - mae: 6.7251 - mse: 282.1992 - val_loss: 82.2341 - val_mae: 6.3791 - val_mse: 82.2341 - learning_rate: 0.0010
# Epoch 57/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 459.2806 - mae: 7.2434 - mse: 459.2806
# Epoch 57: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 267.6077 - mae: 6.9211 - mse: 267.6077 - val_loss: 88.5388 - val_mae: 6.4504 - val_mse: 88.5388 - learning_rate: 0.0010
# Epoch 58/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 726.9400 - mae: 7.4197 - mse: 726.9400
# Epoch 58: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 249ms/step - loss: 292.8096 - mae: 6.7893 - mse: 292.8096 - val_loss: 85.2011 - val_mae: 6.6229 - val_mse: 85.2011 - learning_rate: 0.0010
# Epoch 59/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 475.2220 - mae: 7.0360 - mse: 475.2220
# Epoch 59: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - loss: 282.0946 - mae: 6.8534 - mse: 282.0946 - val_loss: 83.7161 - val_mae: 6.4244 - val_mse: 83.7161 - learning_rate: 0.0010
# Epoch 60/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 134.7008 - mae: 6.0949 - mse: 134.7008
# Epoch 60: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 295ms/step - loss: 277.7975 - mae: 6.6565 - mse: 277.7975 - val_loss: 105.7658 - val_mae: 6.9333 - val_mse: 105.7658 - learning_rate: 0.0010
# Epoch 61/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 120.0833 - mae: 6.5252 - mse: 120.0833
# Epoch 61: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 295ms/step - loss: 266.9243 - mae: 6.6992 - mse: 266.9243 - val_loss: 114.9607 - val_mae: 7.1192 - val_mse: 114.9607 - learning_rate: 0.0010
# Epoch 62/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 151.6396 - mae: 6.6813 - mse: 151.6396
# Epoch 62: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 277.8369 - mae: 6.8447 - mse: 277.8369 - val_loss: 121.2997 - val_mae: 7.2902 - val_mse: 121.2997 - learning_rate: 0.0010
# Epoch 63/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 135.8542 - mae: 6.5005 - mse: 135.8542
# Epoch 63: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 37s 246ms/step - loss: 257.3648 - mae: 6.6544 - mse: 257.3648 - val_loss: 102.7671 - val_mae: 6.8436 - val_mse: 102.7671 - learning_rate: 0.0010
# Epoch 64/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 195.9875 - mae: 6.4533 - mse: 195.9875
# Epoch 64: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 251.8454 - mae: 6.7629 - mse: 251.8454 - val_loss: 82.9691 - val_mae: 6.2557 - val_mse: 82.9691 - learning_rate: 0.0010
# Epoch 65/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 397.5456 - mae: 6.8865 - mse: 397.5456
# Epoch 65: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 46s 300ms/step - loss: 266.7867 - mae: 6.7234 - mse: 266.7867 - val_loss: 90.9183 - val_mae: 6.7166 - val_mse: 90.9183 - learning_rate: 0.0010
# Epoch 66/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 144.2624 - mae: 6.4328 - mse: 144.2624
# Epoch 66: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 237.0557 - mae: 6.6392 - mse: 237.0557 - val_loss: 116.2777 - val_mae: 7.2604 - val_mse: 116.2777 - learning_rate: 0.0010
# Epoch 67/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 609.5719 - mae: 7.3509 - mse: 609.5719
# Epoch 67: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 47s 298ms/step - loss: 316.4069 - mae: 6.8445 - mse: 316.4069 - val_loss: 86.5923 - val_mae: 6.3071 - val_mse: 86.5923 - learning_rate: 0.0010
# Epoch 68/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 98.7805 - mae: 6.2733 - mse: 98.7805
# Epoch 68: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 256.1482 - mae: 6.6140 - mse: 256.1482 - val_loss: 93.4066 - val_mae: 6.8224 - val_mse: 93.4066 - learning_rate: 0.0010
# Epoch 69/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 310.3256 - mae: 7.0064 - mse: 310.3256
# Epoch 69: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 252.1266 - mae: 6.8779 - mse: 252.1266 - val_loss: 85.6255 - val_mae: 6.4235 - val_mse: 85.6255 - learning_rate: 0.0010
# Epoch 70/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 208.7386 - mae: 6.3711 - mse: 208.7386
# Epoch 70: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 214.1089 - mae: 6.3941 - mse: 214.1089 - val_loss: 95.5381 - val_mae: 6.6551 - val_mse: 95.5381 - learning_rate: 0.0010
# Epoch 71/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 206.5753 - mae: 6.2700 - mse: 206.5753
# Epoch 71: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 269ms/step - loss: 241.2471 - mae: 6.6205 - mse: 241.2471 - val_loss: 85.0252 - val_mae: 6.3840 - val_mse: 85.0252 - learning_rate: 0.0010
# Epoch 72/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 114.1784 - mae: 6.5192 - mse: 114.1784
# Epoch 72: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 293ms/step - loss: 250.0070 - mae: 6.5712 - mse: 250.0070 - val_loss: 108.9484 - val_mae: 7.0265 - val_mse: 108.9484 - learning_rate: 0.0010
# Epoch 73/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 245.7330 - mae: 6.6283 - mse: 245.7330
# Epoch 73: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 244.9320 - mae: 6.7052 - mse: 244.9320 - val_loss: 88.1970 - val_mae: 6.4052 - val_mse: 88.1970 - learning_rate: 0.0010
# Epoch 74/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 97.6633 - mae: 6.0477 - mse: 97.6633
# Epoch 74: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - loss: 222.2732 - mae: 6.3755 - mse: 222.2732 - val_loss: 117.6246 - val_mae: 7.5712 - val_mse: 117.6246 - learning_rate: 0.0010
# Epoch 75/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 323.2036 - mae: 7.2113 - mse: 323.2036
# Epoch 75: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 264ms/step - loss: 223.4035 - mae: 6.8627 - mse: 223.4035 - val_loss: 78.0594 - val_mae: 6.3819 - val_mse: 78.0594 - learning_rate: 0.0010
# Epoch 76/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 83.9365 - mae: 6.1103 - mse: 83.9365
# Epoch 76: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 266ms/step - loss: 234.9050 - mae: 6.4734 - mse: 234.9050 - val_loss: 96.3612 - val_mae: 6.5852 - val_mse: 96.3612 - learning_rate: 0.0010
# Epoch 77/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 166.7661 - mae: 6.2327 - mse: 166.7661
# Epoch 77: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - loss: 254.0975 - mae: 6.4868 - mse: 254.0975 - val_loss: 115.8955 - val_mae: 7.1610 - val_mse: 115.8955 - learning_rate: 0.0010
# Epoch 78/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 294.1570 - mae: 6.6883 - mse: 294.1570
# Epoch 78: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - loss: 255.7672 - mae: 6.7283 - mse: 255.7672 - val_loss: 95.2515 - val_mae: 6.5779 - val_mse: 95.2515 - learning_rate: 0.0010
# Epoch 79/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 132.0953 - mae: 6.0685 - mse: 132.0953
# Epoch 79: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 297ms/step - loss: 244.4371 - mae: 6.4491 - mse: 244.4371 - val_loss: 130.9924 - val_mae: 7.2755 - val_mse: 130.9924 - learning_rate: 0.0010
# Epoch 80/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 140.5162 - mae: 6.2896 - mse: 140.5162
# Epoch 80: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 267ms/step - loss: 204.9749 - mae: 6.5177 - mse: 204.9749 - val_loss: 107.9175 - val_mae: 6.9641 - val_mse: 107.9175 - learning_rate: 0.0010
# Epoch 81/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 588.4250 - mae: 7.2671 - mse: 588.4250
# Epoch 81: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - loss: 220.4490 - mae: 6.5838 - mse: 220.4490 - val_loss: 75.2048 - val_mae: 6.2009 - val_mse: 75.2048 - learning_rate: 0.0010
# Epoch 82/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 160.9555 - mae: 6.7292 - mse: 160.9555
# Epoch 82: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 261ms/step - loss: 228.2691 - mae: 6.7303 - mse: 228.2691 - val_loss: 84.4667 - val_mae: 6.3149 - val_mse: 84.4667 - learning_rate: 0.0010
# Epoch 83/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 168.5316 - mae: 6.5060 - mse: 168.5316
# Epoch 83: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 274ms/step - loss: 195.2897 - mae: 6.5006 - mse: 195.2897 - val_loss: 93.2232 - val_mae: 6.5077 - val_mse: 93.2232 - learning_rate: 0.0010
# Epoch 84/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 113.3968 - mae: 6.0469 - mse: 113.3968
# Epoch 84: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 279ms/step - loss: 212.8222 - mae: 6.3748 - mse: 212.8222 - val_loss: 121.8822 - val_mae: 7.0245 - val_mse: 121.8822 - learning_rate: 0.0010
# Epoch 85/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 166.1240 - mae: 6.7523 - mse: 166.1240
# Epoch 85: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 81s 271ms/step - loss: 240.7973 - mae: 6.4558 - mse: 240.7973 - val_loss: 131.6614 - val_mae: 7.4447 - val_mse: 131.6614 - learning_rate: 0.0010
# Epoch 86/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 188.9622 - mae: 6.5569 - mse: 188.9622
# Epoch 86: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 81s 262ms/step - loss: 197.1907 - mae: 6.4923 - mse: 197.1907 - val_loss: 88.6632 - val_mae: 6.5557 - val_mse: 88.6632 - learning_rate: 0.0010
# Epoch 87/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 213.4069 - mae: 6.1743 - mse: 213.4069
# Epoch 87: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 266ms/step - loss: 198.7769 - mae: 6.3084 - mse: 198.7769 - val_loss: 102.1037 - val_mae: 6.8934 - val_mse: 102.1037 - learning_rate: 0.0010
# Epoch 88/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 162.1424 - mae: 6.1674 - mse: 162.1424
# Epoch 88: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 294ms/step - loss: 222.4451 - mae: 6.5837 - mse: 222.4451 - val_loss: 92.3960 - val_mae: 6.6808 - val_mse: 92.3960 - learning_rate: 0.0010
# Epoch 89/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 117.0534 - mae: 6.2927 - mse: 117.0534
# Epoch 89: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 181.3099 - mae: 6.3989 - mse: 181.3099 - val_loss: 107.6169 - val_mae: 6.8884 - val_mse: 107.6169 - learning_rate: 0.0010
# Epoch 90/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 103.3496 - mae: 6.0914 - mse: 103.3496
# Epoch 90: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - loss: 169.3447 - mae: 6.3271 - mse: 169.3447 - val_loss: 96.5891 - val_mae: 6.6786 - val_mse: 96.5891 - learning_rate: 0.0010
# Epoch 91/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 84.4869 - mae: 6.2461 - mse: 84.4869
# Epoch 91: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 273ms/step - loss: 266.4070 - mae: 6.4265 - mse: 266.4070 - val_loss: 102.3792 - val_mae: 7.2708 - val_mse: 102.3792 - learning_rate: 0.0010
# Epoch 92/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 514.4561 - mae: 7.6694 - mse: 514.4561
# Epoch 92: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 190.6554 - mae: 6.7500 - mse: 190.6554 - val_loss: 93.5252 - val_mae: 6.5916 - val_mse: 93.5252 - learning_rate: 0.0010
# Epoch 93/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 166.1285 - mae: 6.1970 - mse: 166.1285
# Epoch 93: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 174.0398 - mae: 6.2657 - mse: 174.0398 - val_loss: 75.0448 - val_mae: 6.1191 - val_mse: 75.0448 - learning_rate: 0.0010
# Epoch 94/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 270.3775 - mae: 6.4333 - mse: 270.3775
# Epoch 94: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 176.9090 - mae: 6.2962 - mse: 176.9090 - val_loss: 82.7637 - val_mae: 6.2965 - val_mse: 82.7637 - learning_rate: 0.0010
# Epoch 95/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 316.9807 - mae: 6.7300 - mse: 316.9807
# Epoch 95: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 193.4132 - mae: 6.4608 - mse: 193.4132 - val_loss: 74.0509 - val_mae: 6.0108 - val_mse: 74.0509 - learning_rate: 0.0010
# Epoch 96/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 70.2282 - mae: 6.0750 - mse: 70.2282
# Epoch 96: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 161.3338 - mae: 6.1873 - mse: 161.3338 - val_loss: 75.1772 - val_mae: 6.1370 - val_mse: 75.1772 - learning_rate: 0.0010
# Epoch 97/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 196.8772 - mae: 6.4583 - mse: 196.8772
# Epoch 97: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 252ms/step - loss: 174.1654 - mae: 6.1954 - mse: 174.1654 - val_loss: 103.4394 - val_mae: 6.6331 - val_mse: 103.4394 - learning_rate: 0.0010
# Epoch 98/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 188.7955 - mae: 6.4562 - mse: 188.7955
# Epoch 98: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 258ms/step - loss: 219.9775 - mae: 6.4450 - mse: 219.9775 - val_loss: 94.1486 - val_mae: 6.4801 - val_mse: 94.1486 - learning_rate: 0.0010
# Epoch 99/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 267.1487 - mae: 6.7229 - mse: 267.1487
# Epoch 99: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 186.3340 - mae: 6.3884 - mse: 186.3340 - val_loss: 81.5804 - val_mae: 6.3192 - val_mse: 81.5804 - learning_rate: 0.0010
# Epoch 100/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 122.6469 - mae: 6.2294 - mse: 122.6469
# Epoch 100: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 248ms/step - loss: 163.0897 - mae: 6.2550 - mse: 163.0897 - val_loss: 87.2931 - val_mae: 6.4310 - val_mse: 87.2931 - learning_rate: 0.0010
# Epoch 101/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 80.6226 - mae: 5.6890 - mse: 80.6226
# Epoch 101: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 249ms/step - loss: 184.7662 - mae: 6.0669 - mse: 184.7662 - val_loss: 93.7573 - val_mae: 6.7287 - val_mse: 93.7573 - learning_rate: 0.0010
# Epoch 102/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 108.5813 - mae: 5.9900 - mse: 108.5813
# Epoch 102: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 255ms/step - loss: 202.3982 - mae: 6.3010 - mse: 202.3982 - val_loss: 88.2133 - val_mae: 6.4276 - val_mse: 88.2133 - learning_rate: 0.0010
# Epoch 103/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 104.3831 - mae: 6.3805 - mse: 104.3831
# Epoch 103: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 166.4723 - mae: 6.2943 - mse: 166.4723 - val_loss: 111.9258 - val_mae: 6.9234 - val_mse: 111.9258 - learning_rate: 0.0010
# Epoch 104/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 153.2783 - mae: 6.2588 - mse: 153.2783
# Epoch 104: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 296ms/step - loss: 171.0639 - mae: 6.2613 - mse: 171.0639 - val_loss: 78.9163 - val_mae: 6.4382 - val_mse: 78.9163 - learning_rate: 0.0010
# Epoch 105/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 317.9115 - mae: 6.6974 - mse: 317.9115
# Epoch 105: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 267ms/step - loss: 181.4843 - mae: 6.2568 - mse: 181.4843 - val_loss: 92.9908 - val_mae: 6.4160 - val_mse: 92.9908 - learning_rate: 0.0010
# Epoch 106/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 166.3134 - mae: 6.2239 - mse: 166.3134
# Epoch 106: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - loss: 204.3147 - mae: 6.3482 - mse: 204.3147 - val_loss: 107.0934 - val_mae: 6.7667 - val_mse: 107.0934 - learning_rate: 0.0010
# Epoch 107/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 257.5371 - mae: 6.4978 - mse: 257.5371
# Epoch 107: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 267ms/step - loss: 156.1047 - mae: 6.2679 - mse: 156.1047 - val_loss: 80.6353 - val_mae: 6.0713 - val_mse: 80.6353 - learning_rate: 0.0010
# Epoch 108/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 77.5735 - mae: 5.9989 - mse: 77.5735
# Epoch 108: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 278ms/step - loss: 171.0974 - mae: 6.1171 - mse: 171.0974 - val_loss: 97.9852 - val_mae: 6.5594 - val_mse: 97.9852 - learning_rate: 0.0010
# Epoch 109/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 193.5974 - mae: 6.4960 - mse: 193.5974
# Epoch 109: val_loss did not improve from 73.24123
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 279ms/step - loss: 122.8259 - mae: 6.1260 - mse: 122.8259 - val_loss: 92.2388 - val_mae: 6.4536 - val_mse: 92.2388 - learning_rate: 0.0010
# Epoch 110/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 155.9483 - mae: 5.9763 - mse: 155.9483
# Epoch 110: val_loss improved from 73.24123 to 71.86916, saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
#
# Epoch 110: finished saving model to /content/drive/MyDrive/Speciale/Models/efficientnetv2b0_rgb_pretrained/best_model.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 282ms/step - loss: 169.0101 - mae: 6.1518 - mse: 169.0101 - val_loss: 71.8692 - val_mae: 6.2331 - val_mse: 71.8692 - learning_rate: 0.0010
# Epoch 111/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 81.3826 - mae: 6.0165 - mse: 81.3826
# Epoch 111: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 81s 275ms/step - loss: 176.9141 - mae: 6.0382 - mse: 176.9141 - val_loss: 104.9457 - val_mae: 6.8879 - val_mse: 104.9457 - learning_rate: 0.0010
# Epoch 112/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 149.6079 - mae: 6.0735 - mse: 149.6079
# Epoch 112: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 46s 299ms/step - loss: 223.0473 - mae: 6.2257 - mse: 223.0473 - val_loss: 127.8679 - val_mae: 7.0944 - val_mse: 127.8679 - learning_rate: 0.0010
# Epoch 113/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 147.5345 - mae: 6.4884 - mse: 147.5345
# Epoch 113: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 273ms/step - loss: 127.3262 - mae: 6.3258 - mse: 127.3262 - val_loss: 79.7553 - val_mae: 6.0984 - val_mse: 79.7553 - learning_rate: 0.0010
# Epoch 114/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 168.8115 - mae: 5.9625 - mse: 168.8115
# Epoch 114: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 248.5572 - mae: 6.2300 - mse: 248.5572 - val_loss: 81.4396 - val_mae: 6.2488 - val_mse: 81.4396 - learning_rate: 0.0010
# Epoch 115/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 144.8687 - mae: 5.9149 - mse: 144.8687
# Epoch 115: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 267ms/step - loss: 234.0336 - mae: 6.1680 - mse: 234.0336 - val_loss: 100.5148 - val_mae: 6.7390 - val_mse: 100.5148 - learning_rate: 0.0010
# Epoch 116/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 109.7299 - mae: 6.1248 - mse: 109.7299
# Epoch 116: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 272ms/step - loss: 141.8152 - mae: 6.2567 - mse: 141.8152 - val_loss: 77.2568 - val_mae: 6.2405 - val_mse: 77.2568 - learning_rate: 0.0010
# Epoch 117/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 98.8720 - mae: 6.0467 - mse: 98.8720
# Epoch 117: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 82s 275ms/step - loss: 154.2513 - mae: 6.1757 - mse: 154.2513 - val_loss: 85.2950 - val_mae: 6.1950 - val_mse: 85.2950 - learning_rate: 0.0010
# Epoch 118/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 66.3629 - mae: 5.9094 - mse: 66.3629
# Epoch 118: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - loss: 122.4329 - mae: 6.1285 - mse: 122.4329 - val_loss: 81.2288 - val_mae: 6.1389 - val_mse: 81.2288 - learning_rate: 0.0010
# Epoch 119/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 215.9086 - mae: 6.5716 - mse: 215.9086
# Epoch 119: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - loss: 158.7808 - mae: 6.2676 - mse: 158.7808 - val_loss: 91.0219 - val_mae: 6.4388 - val_mse: 91.0219 - learning_rate: 0.0010
# Epoch 120/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 136.9425 - mae: 5.9027 - mse: 136.9425
# Epoch 120: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 170.4511 - mae: 6.1963 - mse: 170.4511 - val_loss: 104.9437 - val_mae: 6.3951 - val_mse: 104.9437 - learning_rate: 0.0010
# Epoch 121/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 324.9414 - mae: 6.9098 - mse: 324.9414
# Epoch 121: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 271ms/step - loss: 194.4374 - mae: 6.4806 - mse: 194.4374 - val_loss: 87.9047 - val_mae: 6.1577 - val_mse: 87.9047 - learning_rate: 0.0010
# Epoch 122/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 119.5911 - mae: 6.0120 - mse: 119.5911
# Epoch 122: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 269ms/step - loss: 216.8534 - mae: 6.4409 - mse: 216.8534 - val_loss: 91.2723 - val_mae: 6.4095 - val_mse: 91.2723 - learning_rate: 0.0010
# Epoch 123/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 93.7496 - mae: 5.8340 - mse: 93.7496
# Epoch 123: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 296ms/step - loss: 150.7104 - mae: 5.9907 - mse: 150.7104 - val_loss: 92.8438 - val_mae: 6.4980 - val_mse: 92.8438 - learning_rate: 0.0010
# Epoch 124/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 125.2188 - mae: 6.1663 - mse: 125.2188
# Epoch 124: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - loss: 122.2691 - mae: 6.1150 - mse: 122.2691 - val_loss: 80.1673 - val_mae: 6.0645 - val_mse: 80.1673 - learning_rate: 0.0010
# Epoch 125/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 251.5099 - mae: 6.3300 - mse: 251.5099
# Epoch 125: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 295ms/step - loss: 171.0660 - mae: 6.1433 - mse: 171.0660 - val_loss: 87.1562 - val_mae: 6.1214 - val_mse: 87.1562 - learning_rate: 0.0010
# Epoch 126/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 97.5237 - mae: 6.0573 - mse: 97.5237
# Epoch 126: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - loss: 111.7327 - mae: 6.0257 - mse: 111.7327 - val_loss: 113.8368 - val_mae: 6.6962 - val_mse: 113.8368 - learning_rate: 0.0010
# Epoch 127/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 132.2164 - mae: 5.7698 - mse: 132.2164
# Epoch 127: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 266ms/step - loss: 213.3283 - mae: 6.0736 - mse: 213.3283 - val_loss: 139.2842 - val_mae: 7.0105 - val_mse: 139.2842 - learning_rate: 0.0010
# Epoch 128/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 129.4477 - mae: 6.0912 - mse: 129.4477
# Epoch 128: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 264ms/step - loss: 172.4104 - mae: 6.1751 - mse: 172.4104 - val_loss: 114.2568 - val_mae: 6.5077 - val_mse: 114.2568 - learning_rate: 0.0010
# Epoch 129/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 105.7207 - mae: 6.0621 - mse: 105.7207
# Epoch 129: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - loss: 91.4587 - mae: 5.9033 - mse: 91.4587 - val_loss: 86.9489 - val_mae: 6.1820 - val_mse: 86.9489 - learning_rate: 0.0010
# Epoch 130/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 141.9309 - mae: 5.8258 - mse: 141.9309
# Epoch 130: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 80s 258ms/step - loss: 130.2032 - mae: 5.9328 - mse: 130.2032 - val_loss: 81.0662 - val_mae: 6.0647 - val_mse: 81.0662 - learning_rate: 0.0010
# Epoch 131/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 128.1619 - mae: 6.1065 - mse: 128.1619
# Epoch 131: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 116.3751 - mae: 5.9318 - mse: 116.3751 - val_loss: 91.3195 - val_mae: 6.2093 - val_mse: 91.3195 - learning_rate: 0.0010
# Epoch 132/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 132.6028 - mae: 5.8888 - mse: 132.6028
# Epoch 132: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 251ms/step - loss: 151.0546 - mae: 6.0032 - mse: 151.0546 - val_loss: 84.9582 - val_mae: 6.4370 - val_mse: 84.9582 - learning_rate: 0.0010
# Epoch 133/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 103.8533 - mae: 5.9314 - mse: 103.8533
# Epoch 133: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 115.5483 - mae: 5.9037 - mse: 115.5483 - val_loss: 72.7206 - val_mae: 6.0989 - val_mse: 72.7206 - learning_rate: 0.0010
# Epoch 134/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 231.7974 - mae: 6.1039 - mse: 231.7974
# Epoch 134: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 148.6955 - mae: 5.9210 - mse: 148.6955 - val_loss: 73.9632 - val_mae: 6.0161 - val_mse: 73.9632 - learning_rate: 0.0010
# Epoch 135/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 97.2668 - mae: 5.9932 - mse: 97.2668
# Epoch 135: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 256ms/step - loss: 201.5569 - mae: 6.1630 - mse: 201.5569 - val_loss: 89.6893 - val_mae: 6.2747 - val_mse: 89.6893 - learning_rate: 0.0010
# Epoch 136/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 201.9509 - mae: 6.2172 - mse: 201.9509
# Epoch 136: val_loss did not improve from 71.86916
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 249ms/step - loss: 204.9543 - mae: 6.2485 - mse: 204.9543 - val_loss: 99.1198 - val_mae: 6.4574 - val_mse: 99.1198 - learning_rate: 0.0010
# Epoch 137/300
# ...
# Epoch 252/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 48.3516 - mae: 5.0176 - mse: 48.3516
# Epoch 252: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - loss: 58.6644 - mae: 5.1373 - mse: 58.6644 - val_loss: 70.5103 - val_mae: 5.7346 - val_mse: 70.5103 - learning_rate: 0.0010
# Epoch 253/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 145.0303 - mae: 5.6092 - mse: 145.0303
# Epoch 253: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 75.7047 - mae: 5.3633 - mse: 75.7047 - val_loss: 59.1489 - val_mae: 5.6077 - val_mse: 59.1489 - learning_rate: 0.0010
# Epoch 254/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 61.4175 - mae: 5.3506 - mse: 61.4175
# Epoch 254: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 250ms/step - loss: 60.9392 - mae: 5.2658 - mse: 60.9392 - val_loss: 64.7122 - val_mae: 5.7293 - val_mse: 64.7122 - learning_rate: 0.0010
# Epoch 255/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 61.8357 - mae: 5.2917 - mse: 61.8357
# Epoch 255: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 247ms/step - loss: 57.8918 - mae: 5.2063 - mse: 57.8918 - val_loss: 65.5057 - val_mae: 5.7701 - val_mse: 65.5057 - learning_rate: 0.0010
# Epoch 256/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 52.3187 - mae: 5.1570 - mse: 52.3187
# Epoch 256: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - loss: 50.7469 - mae: 5.1225 - mse: 50.7469 - val_loss: 67.0573 - val_mae: 5.7244 - val_mse: 67.0573 - learning_rate: 0.0010
# Epoch 257/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 47.0085 - mae: 5.0097 - mse: 47.0085
# Epoch 257: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 258ms/step - loss: 48.6806 - mae: 5.0580 - mse: 48.6806 - val_loss: 61.9379 - val_mae: 5.7211 - val_mse: 61.9379 - learning_rate: 0.0010
# Epoch 258/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 48.4238 - mae: 5.1492 - mse: 48.4238
# Epoch 258: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 269ms/step - loss: 52.7967 - mae: 5.2656 - mse: 52.7967 - val_loss: 62.9059 - val_mae: 5.6757 - val_mse: 62.9059 - learning_rate: 0.0010
# Epoch 259/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 83.5348 - mae: 5.5206 - mse: 83.5348
# Epoch 259: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 92.4782 - mae: 5.3754 - mse: 92.4782 - val_loss: 68.2635 - val_mae: 5.7926 - val_mse: 68.2635 - learning_rate: 0.0010
# Epoch 260/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 161.7721 - mae: 5.6473 - mse: 161.7721
# Epoch 260: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 255ms/step - loss: 100.9435 - mae: 5.3601 - mse: 100.9435 - val_loss: 66.5199 - val_mae: 5.6927 - val_mse: 66.5199 - learning_rate: 0.0010
# Epoch 261/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 46.9605 - mae: 4.9671 - mse: 46.9605
# Epoch 261: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 249ms/step - loss: 50.0315 - mae: 5.0885 - mse: 50.0315 - val_loss: 66.0294 - val_mae: 5.8016 - val_mse: 66.0294 - learning_rate: 0.0010
# Epoch 262/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 55.1852 - mae: 5.0792 - mse: 55.1852
# Epoch 262: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 43s 260ms/step - loss: 68.3517 - mae: 5.1656 - mse: 68.3517 - val_loss: 69.3884 - val_mae: 5.9126 - val_mse: 69.3884 - learning_rate: 0.0010
# Epoch 263/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 50.9271 - mae: 5.0167 - mse: 50.9271
# Epoch 263: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 254ms/step - loss: 50.8992 - mae: 5.0832 - mse: 50.8992 - val_loss: 65.9484 - val_mae: 5.8522 - val_mse: 65.9484 - learning_rate: 0.0010
# Epoch 264/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 64.2223 - mae: 5.2322 - mse: 64.2223
# Epoch 264: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 122.3639 - mae: 5.3793 - mse: 122.3639 - val_loss: 63.6629 - val_mae: 5.6427 - val_mse: 63.6629 - learning_rate: 0.0010
# Epoch 265/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 88.0858 - mae: 5.2060 - mse: 88.0858
# Epoch 265: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 58.4911 - mae: 5.1736 - mse: 58.4911 - val_loss: 62.6521 - val_mae: 5.6743 - val_mse: 62.6521 - learning_rate: 0.0010
# Epoch 266/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 68.0255 - mae: 5.3385 - mse: 68.0255
# Epoch 266: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - loss: 67.3848 - mae: 5.1731 - mse: 67.3848 - val_loss: 72.9544 - val_mae: 5.8768 - val_mse: 72.9544 - learning_rate: 0.0010
# Epoch 267/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 51.1321 - mae: 5.0927 - mse: 51.1321
# Epoch 267: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 243ms/step - loss: 70.8567 - mae: 5.1859 - mse: 70.8567 - val_loss: 63.2509 - val_mae: 5.6442 - val_mse: 63.2509 - learning_rate: 0.0010
# Epoch 268/300
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 51.5618 - mae: 5.1340 - mse: 51.5618
# Epoch 268: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 264ms/step - loss: 51.1530 - mae: 5.0980 - mse: 51.1530 - val_loss: 63.9074 - val_mae: 5.6079 - val_mse: 63.9074 - learning_rate: 0.0010
# Epoch 269/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 45.3435 - mae: 4.9542 - mse: 45.3435
# Epoch 269: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 47.9944 - mae: 5.0368 - mse: 47.9944 - val_loss: 67.5023 - val_mae: 5.6940 - val_mse: 67.5023 - learning_rate: 0.0010
# Epoch 270/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 57.4887 - mae: 5.1670 - mse: 57.4887
# Epoch 270: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 254ms/step - loss: 93.5625 - mae: 5.2180 - mse: 93.5625 - val_loss: 66.5601 - val_mae: 5.6896 - val_mse: 66.5601 - learning_rate: 0.0010
# Epoch 271/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 48.2246 - mae: 5.0672 - mse: 48.2246
# Epoch 271: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 263ms/step - loss: 50.4464 - mae: 5.0576 - mse: 50.4464 - val_loss: 61.3467 - val_mae: 5.5849 - val_mse: 61.3467 - learning_rate: 0.0010
# Epoch 272/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 136.7551 - mae: 5.2443 - mse: 136.7551
# Epoch 272: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 80.1007 - mae: 5.0728 - mse: 80.1007 - val_loss: 61.9661 - val_mae: 5.5592 - val_mse: 61.9661 - learning_rate: 0.0010
# Epoch 273/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 43.7036 - mae: 4.7989 - mse: 43.7036
# Epoch 273: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 254ms/step - loss: 50.0561 - mae: 4.9988 - mse: 50.0561 - val_loss: 81.6335 - val_mae: 6.2184 - val_mse: 81.6335 - learning_rate: 0.0010
# Epoch 274/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 55.0014 - mae: 5.1598 - mse: 55.0014
# Epoch 274: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 105.0124 - mae: 5.1765 - mse: 105.0124 - val_loss: 59.5848 - val_mae: 5.6126 - val_mse: 59.5848 - learning_rate: 0.0010
# Epoch 275/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 308.1017 - mae: 6.1154 - mse: 308.1017
# Epoch 275: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 258ms/step - loss: 109.6660 - mae: 5.4800 - mse: 109.6660 - val_loss: 64.3704 - val_mae: 5.7614 - val_mse: 64.3704 - learning_rate: 0.0010
# Epoch 276/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 52.8279 - mae: 4.9657 - mse: 52.8279
# Epoch 276: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 257ms/step - loss: 52.5715 - mae: 5.1106 - mse: 52.5715 - val_loss: 67.5595 - val_mae: 5.7923 - val_mse: 67.5595 - learning_rate: 0.0010
# Epoch 277/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 51.5666 - mae: 5.1315 - mse: 51.5666
# Epoch 277: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 263ms/step - loss: 57.6510 - mae: 5.1214 - mse: 57.6510 - val_loss: 60.0234 - val_mae: 5.5638 - val_mse: 60.0234 - learning_rate: 0.0010
# Epoch 278/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 69.3929 - mae: 5.3638 - mse: 69.3929
# Epoch 278: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 257ms/step - loss: 60.4564 - mae: 5.0974 - mse: 60.4564 - val_loss: 59.7524 - val_mae: 5.5326 - val_mse: 59.7524 - learning_rate: 0.0010
# Epoch 279/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 46.3065 - mae: 4.9551 - mse: 46.3065
# Epoch 279: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - loss: 49.8844 - mae: 4.9675 - mse: 49.8844 - val_loss: 63.6644 - val_mae: 5.5958 - val_mse: 63.6644 - learning_rate: 0.0010
# Epoch 280/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 76.2183 - mae: 5.1552 - mse: 76.2183
# Epoch 280: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 42s 259ms/step - loss: 82.2893 - mae: 5.2864 - mse: 82.2893 - val_loss: 65.0278 - val_mae: 5.7409 - val_mse: 65.0278 - learning_rate: 0.0010
# Epoch 281/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 51.5957 - mae: 4.9861 - mse: 51.5957
# Epoch 281: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 62.7281 - mae: 5.0703 - mse: 62.7281 - val_loss: 64.3856 - val_mae: 5.7826 - val_mse: 64.3856 - learning_rate: 0.0010
# Epoch 282/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 54.9001 - mae: 5.2691 - mse: 54.9001
# Epoch 282: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 290ms/step - loss: 55.2037 - mae: 5.1993 - mse: 55.2037 - val_loss: 64.0489 - val_mae: 5.7361 - val_mse: 64.0489 - learning_rate: 0.0010
# Epoch 283/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 198.0252 - mae: 5.6288 - mse: 198.0252
# Epoch 283: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 145.8150 - mae: 5.3637 - mse: 145.8150 - val_loss: 66.8565 - val_mae: 5.8305 - val_mse: 66.8565 - learning_rate: 0.0010
# Epoch 284/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 88.2555 - mae: 5.0289 - mse: 88.2555
# Epoch 284: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 289ms/step - loss: 61.0702 - mae: 4.8317 - mse: 61.0702 - val_loss: 65.1461 - val_mae: 5.6455 - val_mse: 65.1461 - learning_rate: 0.0010
# Epoch 285/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 52.8954 - mae: 5.0503 - mse: 52.8954
# Epoch 285: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 291ms/step - loss: 66.5082 - mae: 5.0422 - mse: 66.5082 - val_loss: 77.0666 - val_mae: 5.9248 - val_mse: 77.0666 - learning_rate: 0.0010
# Epoch 286/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 58.1163 - mae: 5.1889 - mse: 58.1163
# Epoch 286: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 288ms/step - loss: 101.8841 - mae: 5.2998 - mse: 101.8841 - val_loss: 68.2007 - val_mae: 5.8387 - val_mse: 68.2007 - learning_rate: 0.0010
# Epoch 287/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 69.1211 - mae: 5.1954 - mse: 69.1211
# Epoch 287: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 75.6316 - mae: 5.2414 - mse: 75.6316 - val_loss: 69.4141 - val_mae: 5.7732 - val_mse: 69.4141 - learning_rate: 0.0010
# Epoch 288/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 60.7442 - mae: 5.3172 - mse: 60.7442
# Epoch 288: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 248ms/step - loss: 50.5674 - mae: 5.1252 - mse: 50.5674 - val_loss: 71.8100 - val_mae: 5.8941 - val_mse: 71.8100 - learning_rate: 0.0010
# Epoch 289/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 51.4095 - mae: 4.8996 - mse: 51.4095
# Epoch 289: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 51.7402 - mae: 4.9483 - mse: 51.7402 - val_loss: 70.9503 - val_mae: 5.8368 - val_mse: 70.9503 - learning_rate: 0.0010
# Epoch 290/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 51.1335 - mae: 5.1062 - mse: 51.1335
# Epoch 290: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 53.0401 - mae: 5.1316 - mse: 53.0401 - val_loss: 69.5093 - val_mae: 5.7959 - val_mse: 69.5093 - learning_rate: 0.0010
# Epoch 291/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 61.0817 - mae: 5.0333 - mse: 61.0817
# Epoch 291: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 255ms/step - loss: 54.6225 - mae: 5.0406 - mse: 54.6225 - val_loss: 62.2931 - val_mae: 5.7005 - val_mse: 62.2931 - learning_rate: 0.0010
# Epoch 292/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 47.9716 - mae: 5.0531 - mse: 47.9716
# Epoch 292: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 252ms/step - loss: 47.8247 - mae: 5.0489 - mse: 47.8247 - val_loss: 73.7407 - val_mae: 5.9102 - val_mse: 73.7407 - learning_rate: 0.0010
# Epoch 293/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 107.2108 - mae: 5.1061 - mse: 107.2108
# Epoch 293: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 97.0041 - mae: 5.1700 - mse: 97.0041 - val_loss: 64.6171 - val_mae: 5.7568 - val_mse: 64.6171 - learning_rate: 0.0010
# Epoch 294/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 68.2263 - mae: 5.1375 - mse: 68.2263
# Epoch 294: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - loss: 65.7220 - mae: 5.1528 - mse: 65.7220 - val_loss: 65.3527 - val_mae: 5.7831 - val_mse: 65.3527 - learning_rate: 0.0010
# Epoch 295/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 56.1926 - mae: 5.2488 - mse: 56.1926
# Epoch 295: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 260ms/step - loss: 71.3044 - mae: 5.2356 - mse: 71.3044 - val_loss: 69.1743 - val_mae: 5.8303 - val_mse: 69.1743 - learning_rate: 0.0010
# Epoch 296/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 61.2281 - mae: 5.0871 - mse: 61.2281
# Epoch 296: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 45s 288ms/step - loss: 55.4582 - mae: 5.0761 - mse: 55.4582 - val_loss: 61.5607 - val_mae: 5.6015 - val_mse: 61.5607 - learning_rate: 0.0010
# Epoch 297/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 42.9937 - mae: 4.6708 - mse: 42.9937
# Epoch 297: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 49.8994 - mae: 4.8416 - mse: 49.8994 - val_loss: 67.4797 - val_mae: 5.7170 - val_mse: 67.4797 - learning_rate: 0.0010
# Epoch 298/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 51.8334 - mae: 4.8634 - mse: 51.8334
# Epoch 298: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 38s 250ms/step - loss: 57.2030 - mae: 5.0624 - mse: 57.2030 - val_loss: 59.8295 - val_mae: 5.5460 - val_mse: 59.8295 - learning_rate: 0.0010
# Epoch 299/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 46.8495 - mae: 4.8089 - mse: 46.8495
# Epoch 299: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 47.3545 - mae: 4.9005 - mse: 47.3545 - val_loss: 67.8508 - val_mae: 5.7368 - val_mse: 67.8508 - learning_rate: 0.0010
# Epoch 300/300
# 151/152 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 59.8224 - mae: 5.1768 - mse: 59.8224
# Epoch 300: val_loss did not improve from 57.37492
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 44s 293ms/step - loss: 90.7032 - mae: 5.0603 - mse: 90.7032 - val_loss: 66.6441 - val_mae: 5.8236 - val_mse: 66.6441 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 231.

# %% [markdown]
# Plotting

# %%
def plot_metrics(history):
    h = history.history
    epochs = np.arange(1, len(h["loss"]) + 1)

    fig, axes = plt.subplots(1, 3, figsize=(18, 4))

    axes[0].plot(epochs, h["loss"], marker="o", label="Train Loss")
    axes[0].plot(epochs, h["val_loss"], marker="o", label="Val Loss")
    axes[0].set_title("Loss (MSE)")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].legend()
    axes[0].grid(True, linestyle="--", alpha=0.5)

    if "mae" in h and "val_mae" in h:
        axes[1].plot(epochs, h["mae"], marker="o", label="Train MAE")
        axes[1].plot(epochs, h["val_mae"], marker="o", label="Val MAE")
        axes[1].set_title("Mean Absolute Error")
        axes[1].set_xlabel("Epoch")
        axes[1].set_ylabel("MAE")
        axes[1].legend()
        axes[1].grid(True, linestyle="--", alpha=0.5)

    if "mse" in h and "val_mse" in h:
        axes[2].plot(epochs, h["mse"], marker="o", label="Train MSE")
        axes[2].plot(epochs, h["val_mse"], marker="o", label="Val MSE")
        axes[2].set_title("Mean Squared Error")
        axes[2].set_xlabel("Epoch")
        axes[2].set_ylabel("MSE")
        axes[2].legend()
        axes[2].grid(True, linestyle="--", alpha=0.5)

    plt.tight_layout()
    plt.show()

    best = np.argmin(h["val_loss"])
    print(f"Best val_loss: {h['val_loss'][best]:.4f} at epoch {best + 1}")

    if "val_mae" in h:
        print(f"Val MAE at best epoch: {h['val_mae'][best]:.4f}")
    if "val_mse" in h:
        print(f"Val MSE at best epoch: {h['val_mse'][best]:.4f}")


plot_metrics(history)
# Out:
# Best val_loss: 57.3749 at epoch 231
# Val MAE at best epoch: 5.5472
# Val MSE at best epoch: 57.3749

# %% [markdown]
# Evaluation on test set

# %%
loaded_model = tf.keras.models.load_model(str(OUTPUT_DIR / "best_model.keras"))

# %%
loaded_model_test_results = loaded_model.evaluate(test_dataset, return_dict=True)
print(loaded_model_test_results)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 128s 3s/step - loss: 86.5800 - mae: 6.4522 - mse: 86.5800
# {'loss': 86.58003234863281, 'mae': 6.4522385597229, 'mse': 86.58003234863281}

# %%
test_results = model.evaluate(test_dataset, return_dict=True)
print(test_results)
